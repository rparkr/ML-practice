# %% [markdown]
# # Data Collection: Vehicle Info
# > An exercise for my Machine Learning in Python course, to gather data to be used for running machine learning models.
# In Google Colab, all code in this notebook can be run in approximately 50 minutes.
#
# **Author:** [Ryan Parker](https://github.com/rparkr)
#
# **Updated on:** 10-Nov-2021
#
#
# ---
#
#
# ## Data Sources
# * Vehicle specs: [CarAndDriver.com](https://www.caranddriver.com/volkswagen/atlas/specs/2021/volkswagen_atlas_volkswagen-atlas_2021/417662)
# * Vehicle origin: Percent of Vehicle Content from North America (US/Canada), [data from the NHTSA American Automobile Labeling Act](https://www.nhtsa.gov/part-583-american-automobile-labeling-act-reports)
#  * [PDF for model year 2021](https://www.nhtsa.gov/sites/nhtsa.gov/files/2021-06/MY2021-AALA-Alphabetical-6-30-21.pdf) passenger vehicles
#  * Converted PDF to Excel using [Adobe Acrobat free PDF to Excel converter](https://www.adobe.com/acrobat/online/pdf-to-excel.html), then heavily cleaned in Excel prior to saving as a .csv file for import in this notebook
#
# **Other interesting data (not used here, but related)**
# * [GoodCarBadCar.net](https://www.goodcarbadcar.net/2021-us-vehicle-sales-figures-by-model/), model-level vehicle sales data by year
# * [List of new vehicle models and makes](https://www.kbb.com/car-make-model-list/new/view-all/make/), from Kelley Blue Book
# * FuelEconomy.gov, the EPA's official source for vehicle fuel economy data. Available as a [CSV download](https://www.fueleconomy.gov/feg/download.shtml), with over 44k rows of data and [83 columns](https://www.fueleconomy.gov/feg/ws/index.shtml#vehicle), and also as a [Web Services API](https://www.fueleconomy.gov/feg/ws/index.shtml). Contains data for vehicle models from 1984-present
#
# ## Background
# When searching for vehicles on Google (e.g., "[2021 Honda Civic](https://www.google.com/search?q=2021+honda+civic)"), I noticed that Google presented summarized specs for a vehicle (like weight, length, number of seats, and towing capacity) which were sourced from CarAndDriver.com. Car and Driver maintains comprehensive vehicle statistics for hundreds of models and trim levels for vehicles produced within the past few years.
#
# This Jupyter Notebook walks through my process to collect and organize data from CarAndDriver.com to use for testing machine learning models.
#
# ## Data collected
# **General info**
# * Year
# * Make
# * Model
# * Image URL
# * Style (configuration)
# * Trim
# * Origin (domestic or foreign)
# * Price (starting MSRP)
# * EPA classification (vehicle class)
#
# **Engine**
#
# * Drivetrain (rear/front-wheel drive or AWD)
# * Engine type
# * Fuel type
# * Engine displacement (L)
# * Engine displacement (in$^3$)
# * Max horsepower
# * RPM for max HP
# * Max torque
# * RPM for max torque
# * Transmission type
# * Transmission speeds (gears)
#
# **Fuel economy**
#
# * CO$_2$ emissions (in tons)
# * Range, city (miles)
# * Range, highway (miles)
# * MPG, combined
# * MPG, city
# * MPG, hwy
# * Fuel tank capacity (gallons)
#
# **Dimensions**
#
# * Wheelbase (inches)
# * Length (inches)
# * Width, without mirrors (inches)
# * Height (inches)
# * Ground clearance (inches)
# * Turning diameter (feet)
# * Front wheel size (inches)
# * Rear wheel size (inches)
# * Seating capacity
# * Total passenger volume (ft$^3$)
# * Cargo space (ft$^3$)
# * Curb weight (pounds)
# * GVWR (pounds)
# * Payload capacity (pounds)
# * Towing capacity (pounds)

# %% [markdown]
# # Steps for data collection
# 1. Access https://www.caranddriver.com
# 2. Collect all makes (links to vehicle brands) from the New Cars menu of https://www.caranddriver.com/#sidepanel
# 3. On each make (brand) page (e.g., https://www.caranddriver.com/honda), loop through featured vehicles and collect links to the pages for those vehicles
# 4. Process the links to vehicle models by retrieving info from the specs page for each model, which has a URL of the form: `https://www.caranddriver.com/[MAKE]/[MODEL]/specs`
#  * Collect the Style (configuration) and Trim IDs for each model by looping through the options in the drop-down boxes at the top of the vehicle specs page
#  * Retrieve data for each Style and Trim combination, from a URL of the format: `https://www.caranddriver.com/[MAKE]/[MODEL]/specs/[YEAR]/[STYLE]/[TRIM_ID]`
# 5. Store the data in a `pandas` `DataFrame` that can be saved to a `.csv` file or a `.db` SQLite database for later use

# %% [markdown]
# ## Import Python packages for data collection

# %%
# import needed packages (libraries)
import requests                 # for requesting web pages (HTML content of pages)
from bs4 import BeautifulSoup   # for parsing HTML
import pandas as pd             # for storing and analyzing data in a tabular format
import sqlite3                  # for storing a copy of the data in a SQLite database
import re                       # for text-based pattern matching
import time                     # for pausing 10ms between each webpage request
import datetime                 # for getting the current year (if needed as proxy for model year)
import json                     # to work with HTML in structured JSON format (dictionaries and lists)

# import seaborn as sns           # statistical data visualization
# import matplotlib.pyplot as plt # general plotting and visualization

# %%
# (Optional) Load vehicle Fuel Economy dataset from FuelEconomy.gov

# Has over 44k rows and 83 columns
# Takes about 15 seconds to load into the DataFrame

# df_fuelecon = pd.read_csv('https://www.fueleconomy.gov/feg/epadata/vehicles.csv', low_memory=False)

# print(df_fuelecon.shape)
# df_fuelecon.head()

# %% [markdown]
# ## Connect to CarAndDriver.com
# ...and load a dictionary of links to each automaker's page
#
# ## First, check `robots.txt`
# I checked Car and Driver's [`robots.txt` page](https://www.caranddriver.com/robots.txt) and confirmed that the pages I will be using are allowed for web scraping, with a crawl delay of 10ms.

# %%
main_url = 'https://www.caranddriver.com'

sesh = requests.session()
response = sesh.get(f'{main_url}')
page = BeautifulSoup(response.text, 'html.parser')

# Create a dictionary to hold the make (brand) and the URL to its page
makes = {}

# Collect links to each page, from the side navigation menu on the main page
# For an example, see: https://beautiful-soup-4.readthedocs.io/en/latest/#quick-start
for link in page.find(id='submenu_newcars').find_all('a'):
    makes[link.text] = main_url + link.get('href')

# View the resulting dictionary
makes
# Out:
# {'Acura': 'https://www.caranddriver.com/acura',
#  'Alfa Romeo': 'https://www.caranddriver.com/alfa-romeo',
#  'Aston Martin': 'https://www.caranddriver.com/aston-martin',
#  'Audi': 'https://www.caranddriver.com/audi',
#  'BMW': 'https://www.caranddriver.com/bmw',
#  'Bentley': 'https://www.caranddriver.com/bentley',
#  'Bollinger': 'https://www.caranddriver.com/bollinger',
#  'Bugatti': 'https://www.caranddriver.com/bugatti',
#  'Buick': 'https://www.caranddriver.com/buick',
#  'Byton': 'https://www.caranddriver.com/byton',
#  'Cadillac': 'https://www.caranddriver.com/cadillac',
#  'Chevrolet': 'https://www.caranddriver.com/chevrolet',
#  'Chrysler': 'https://www.caranddriver.com/chrysler',
#  'Dodge': 'https://www.caranddriver.com/dodge',
#  'Ferrari': 'https://www.caranddriver.com/ferrari',
#  'Fiat': 'https://www.caranddriver.com/fiat',
#  'Fisker': 'https://www.caranddriver.com/fisker',
#  'Ford': 'https://www.caranddriver.com/ford',
#  'GMC': 'https://www.caranddriver.com/gmc',
#  'Genesis': 'https://www.caranddriver.com/genesis',
#  'Honda': 'https://www.caranddriver.com/honda',
#  'Hyundai': 'https://www.caranddriver.com/hyundai',
#  'Infiniti': 'https://www.caranddriver.com/infiniti',
#  'Jaguar': 'https://www.caranddriver.com/jaguar',
#  'Jeep': 'https://www.caranddriver.com/jeep',
#  'Karma': 'https://www.caranddriver.com/karma',
#  'Kia': 'https://www.caranddriver.com/kia',
#  'Koenigsegg': 'https://www.caranddriver.com/koenigsegg',
#  'Lamborghini': 'https://www.caranddriver.com/lamborghini',
#  'Land Rover': 'https://www.caranddriver.com/land-rover',
#  'Lexus': 'https://www.caranddriver.com/lexus',
#  'Lincoln': 'https://www.caranddriver.com/lincoln',
#  'Lordstown': 'https://www.caranddriver.com/lordstown',
#  'Lotus': 'https://www.caranddriver.com/lotus',
#  'Lucid Motors': 'https://www.caranddriver.com/lucid-motors',
#  'Maserati': 'https://www.caranddriver.com/maserati',
#  'Mazda': 'https://www.caranddriver.com/mazda',
#  'McLaren': 'https://www.caranddriver.com/mclaren',
#  'Mercedes-AMG': 'https://www.caranddriver.com/mercedes-amg',
#  'Mercedes-Benz': 'https://www.caranddriver.com/mercedes-benz',
#  'Mercedes-Maybach': 'https://www.caranddriver.com/mercedes-maybach',
#  'Mini': 'https://www.caranddriver.com/mini',
#  'Mitsubishi': 'https://www.caranddriver.com/mitsubishi',
#  'Nikola': 'https://www.caranddriver.com/nikola',
#  'Nissan': 'https://www.caranddriver.com/nissan',
#  'Polestar': 'https://www.caranddriver.com/polestar',
#  'Porsche': 'https://www.caranddriver.com/porsche',
#  'Ram': 'https://www.caranddriver.com/ram',
#  'Rivian': 'https://www.caranddriver.com/rivian',
#  'Rolls-Royce': 'https://www.caranddriver.com/rolls-royce',
#  'Subaru': 'https://www.caranddriver.com/subaru',
#  'Tesla': 'https://www.caranddriver.com/tesla',
#  'Toyota': 'https://www.caranddriver.com/toyota',
#  'Volkswagen': 'https://www.caranddriver.com/volkswagen',
#  'Volvo': 'https://www.caranddriver.com/volvo'}

# %% [markdown]
# ## Get links to pages for each model
# > The code cell below takes around 25 seconds to run in Google Colab.

# %%
# Loop through automakers' pages and collect links to all models for that make

# Create dictionary. Keys will be model names. Values will be sub-dictionaries
# with key-value pairs representing the page attributes for a model.
models = {}

# Lists for checking if a model has already been added
lowercase_models = []
model_url_list = []

# Loop through all make pages to find all models under that brand
for make_name, make_url in makes.items():
    page = BeautifulSoup(requests.get(url=make_url).text, 'html.parser')
    # Use list comprehension to create a list of all models on the page
    links = [item.find('a') for item in page.find_all('div', {'class':'vehicle-item-body'})]
    for link in links:
        year_name = link.text.split(sep=' ', maxsplit=1)      # e.g., "2022 Honda Pilot"
        # If model year not present, assume model name only
        if len(year_name) == 1:
            # See: https://www.kite.com/python/examples/5639/datetime-get-the-year,-month,-and-day-of-a-%60datetime%60
            # Also: https://www.geeksforgeeks.org/python-program-to-print-current-year-month-and-day/
            model_year = datetime.datetime.today().year
            model_name = year_name[0]
        else:
            model_year = year_name[0]
            model_name = year_name[1]
        model_url = main_url + link.get('href')

        # Skip to the next model if the model_year is non-numeric
        try:
            int(model_year)
        except ValueError:
            continue
        # See code cell below for a RegEx demonstration for this technique
        # If a year is appended to the end of the model url, it may be a repeat
        # model, since multiple years can be accessed from the same specs page.
        # e.g., 'https://www.caranddriver.com/honda/civic-2021' is the same as
        #       'https://www.caranddriver.com/honda/civic'
        model_url_no_year = re.split(pattern='-[0-9]{4}$', string=model_url, maxsplit=1)[0]

        # Check if the model already exists in the dictionary
        if (model_name.lower() in lowercase_models) or (model_url_no_year in model_url_list):
            continue    # skip to the next model on the page
        
        # Add to the model name and url lists
        lowercase_models.append(model_name.lower())
        model_url_list.append(model_url_no_year)
        
        models[model_name] = dict(
            Make = make_name, 
            Year = model_year, 
            URL = model_url
        )
    # Pause Python for 10ms before going to the next automaker page
    # See: https://www.kite.com/python/answers/how-to-sleep-for-a-number-of-milliseconds-in-python
    time.sleep(0.01)

# View the models dictionary
# models

# %%
# Example: demonstrating use of RegEx to find model duplicates from URLs
# Simple documentation here: https://www.w3schools.com/python/python_regex.asp
# More thorough overview here: https://docs.python.org/3/howto/regex.html

# # Use a regular expression to find if a year is appended to the end of a URL
test_url = 'https://www.caranddriver.com/honda/civic-2021'

look_for = re.search(pattern='-[0-9]{4}$', string=test_url)
if look_for == None:
    print('No match found')
else:
    print('Match found:', test_url[look_for.start():look_for.end()])
    print('Before match:', test_url[:look_for.start()])

print(re.split(pattern='-[0-9]{4}$', string=test_url, maxsplit=1))
# Out:
# Match found: -2021
# Before match: https://www.caranddriver.com/honda/civic
# ['https://www.caranddriver.com/honda/civic', '']

# %% [markdown]
# ## Add vehicle origin to model list
# Vehicle origin information comes from the National Highway and Traffic Safety Administration (NHTSA), which requires that every automaker publicly post information regarding the percentage of vehicle components (by value, not quantity) and labor from the United States and Canada, and, if applicable, from the next two most prevalent countries. See the **[Data Sources](#scrollTo=Data_Collection_Vehicle_Info)** section in the intro.
#
# > I use vehicle origin data to determine whether a model is _domestic_ (i.e., mostly from the U.S. and Canada) or _foreign_ (mostly from other countries).
#
# In the code below, I use RegEx (regular expressions) to evaluate whether the Origin dataset has information for a particular model in the `models` dictionary. `pandas` provides faster methods for looking for values, like [`'value' in df['col']`](https://www.kite.com/python/answers/how-to-check-if-a-value-exists-in-a-pandas-dataframe-in-python), or [`df['col'].isin(['value'])`](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#indexing-with-isin), and even methods for combining data automatically, like `df.join()` or `df.merge()`.
#
# The reason I use the slower RegEx method is that the models and makes are occassionally listed differently across the two datasets. The `models` dictionary tends to have the full model and make names, and the Origin datasets usually have shorter versions of the full model names. For example, I would like `Silverado` in the Origin dataset to match `Silverado 1500` and `Silverado HD` in the `models` dictionary. Thus, I use RegEx to check each Origin model to see if it has a match in the `models` dictionary.

# %%
# Load the datasets with vehicle origin information
df_make_origin = pd.read_csv('https://raw.githubusercontent.com/rparkr/ML-practice/main/Vehicle%20specs/Make_2021_Domestic_Content.csv')
df_model_origin = pd.read_csv(
    'https://raw.githubusercontent.com/rparkr/ML-practice/main/Vehicle%20specs/Models_2021_Domestic_Content.csv', 
    encoding='latin-1')

# Loop through the models dictionary and add origin information
for vehicle_model, vehicle_attributes in models.items():
    match_found = None     # Reset match_found variable
    origin_pct = 0      # Reset the origin_pct variable

    # First, check if the vehicle make is in the df_make_origin dataset
    for num, item in enumerate(df_make_origin['Make']):
        # Search using the first 5 letters of make name
        match_found = re.search(item[:5].lower(), vehicle_attributes['Make'].lower())
        if match_found != None:
            # Save the matched info, in case a model is not found later
            origin_pct = df_make_origin.at[num, 'Avg Domestic Content']
            # Exit this inner loop since vehicle make was found
            break
    
    if match_found == None:
        # Data for make not available, return an empty value for the model
        vehicle_attributes['Pct_domestic_content'] = ''
        continue    # Move to the next vehicle_model in the models dictionary
    
    # Next, check if the model is in the df_model_origin dataset
    match_found = None     # Reset match_found variable
    for num, item in enumerate(df_model_origin['Model']):
        # Search using the first 5 characters of model name, which has an average len of 5 characters
        match_found = re.search(item[:5].lower(), vehicle_model.lower())
        if match_found != None:
            # Add origin information to the model
            origin_pct = df_model_origin.at[num, 'Avg Domestic Content']
            # Exit this inner loop since vehicle model was found
            break

    # Add origin_pct to the vehicle_model
    # If model was not not found, this is the average value from the make
    # If model was found, this is the value for the model
    vehicle_attributes['Pct_domestic_content'] = origin_pct

# View the models dictionary
# models

# %%
# Create a pandas DataFrame of the vehicle models, transposed so model names are the rows
df_models = pd.DataFrame.from_dict(models).T

# Reset the index
df_models.reset_index(inplace=True)

# Rename the new 'index' column as 'Model'
df_models.rename(columns={'index':'Model'}, inplace=True)

# Save to a .csv
df_models.to_csv('model_urls.csv', index=False, encoding='latin1')

# display the DataFrame
print('Rows:\t', df_models.shape[0], '\nCols:\t', df_models.shape[1])
df_models.head()
# Out:
# Rows:	 764
# Cols:	 5
#         Model  ... Pct_domestic_content
# 0     Integra  ...                 0.64
# 1         MDX  ...                 0.64
# 2         ILX  ...                 0.55
# 3  NSX Type S  ...                 0.64
# 4         RDX  ...                 0.65
#
# [5 rows x 5 columns]

# %% [markdown]
# ## Gather vehicle specs for each model by Trim ID

# %% [markdown]
# ### Create a dictionary to hold the data
# This dictionary is formatted like a DataFrame: the keys are columns, and the values of each key are a list of values (the data of that column)

# %%
# Use a dictionary comprehension to create the dictionary

column_names = [
    'Trim_ID', 'Make', 'Model', 'Year', 'Style',  'Trim', 'Trim_ID', 
    'Body_style', 'EPA_class', 'Pct_domestic_content', 'Origin', 'URL', 'Image', 
    'Price', 'Drivetrain', 'Engine', 'Engine_size_liters', 'Engine_size_inches', 
    'Max_horsepower', 'RPM_max_hp', 'Max_torque', 'RPM_max_torque', 
    'Transmission_type', 'Transmission_gears', 'CO2_emmissions', 'MPG_city',  
    'MPG_highway', 'MPG_combined', 'Fuel_capacity_gallons', 'Range_combined', 
    'Range_city', 'Range_highway', 'Wheelbase_inches', 'Length_inches', 
    'Width_inches', 'Height_inches', 'Ground_clearance_inches', 
    'Turning_diameter_ft', 'Front_wheel_size_inches', 'Rear_wheel_size_inches', 
    'Same_size_wheels', 'Seating_capacity', 'Cabin_volume_cubic_ft', 
    'Cargo_space_cubic_ft', 'GVWR_pounds', 'Curb_weight_pounds', 
    'Payload_capacity_pounds', 'Towing_capacity_pounds']

vehicle_specs = {item:list() for item in column_names}

# View the number of columns in the dataset
print('Cols: ', len(vehicle_specs), '\n', sep='')

# View the resulting dictionary
vehicle_specs
# Out:
# Cols: 47
# {'Body_style': [],
#  'CO2_emmissions': [],
#  'Cabin_volume_cubic_ft': [],
#  'Cargo_space_cubic_ft': [],
#  'Curb_weight_pounds': [],
#  'Drivetrain': [],
#  'EPA_class': [],
#  'Engine': [],
#  'Engine_size_inches': [],
#  'Engine_size_liters': [],
#  'Front_wheel_size_inches': [],
#  'Fuel_capacity_gallons': [],
#  'GVWR_pounds': [],
#  'Ground_clearance_inches': [],
#  'Height_inches': [],
#  'Image': [],
#  'Length_inches': [],
#  'MPG_city': [],
#  'MPG_combined': [],
#  'MPG_highway': [],
#  'Make': [],
#  'Max_horsepower': [],
#  'Max_torque': [],
#  'Model': [],
#  'Origin': [],
#  'Payload_capacity_pounds': [],
#  'Pct_domestic_content': [],
#  'Price': [],
#  'RPM_max_hp': [],
#  'RPM_max_torque': [],
#  'Range_city': [],
#  'Range_combined': [],
#  'Range_highway': [],
#  'Rear_wheel_size_inches': [],
#  'Same_size_wheels': [],
#  'Seating_capacity': [],
#  'Style': [],
#  'Towing_capacity_pounds': [],
#  'Transmission_gears': [],
#  'Transmission_type': [],
#  'Trim': [],
#  'Trim_ID': [],
#  'Turning_diameter_ft': [],
#  'URL': [],
#  'Wheelbase_inches': [],
#  'Width_inches': [],
#  'Year': []}

# %% [markdown]
# ### Write functions for data collection
# In this section, I create two functions:
# 1. A function to remove any non-numeric characters from a string (for cleaning data prior to saving it in the DataFrame)
# 2. A function to return an item of information from the CarAndDriver spec pages
#
# This is important because the CarAndDriver spec pages don't assign a unique ID or name attribute to the page elements that hold data. Since I cannot locate an element with particular data by its unique ID, I must search for the label text (e.g., "Fuel Capacity") using a RegEx pattern, and then return the text from the next element in the HTML doc.
#
# This function accomplishes that task by returning the data point based on a search of the displayed text on the page's HTML.

# %%
def numbers_only(input_string: str):
    '''
    Converts a string into its numeric equivalent by 
    removing any non-numeric characters. 
    Numeric digits include the numbers 0-9 and "."

    Note: This works for only positive numbers
    '''
    import re
    # RegEx version to extract numbers from a string:
    # ===============================================
    # Here's what it does: 1 or more digits (\d, which is the equivalent of [0-9]) 
    # followed by any number of digits or commas, followed by up to 1 decimal place, 
    # followed by 0 or more digits.

    match_found = re.search(pattern=r'\d+[0-9,]*[.]?\d*', string=input_string)
    if match_found != None:
        match = match_found.group()
        num_only = re.sub(pattern=',', repl='', string=match)
        try:
            return_val = float(num_only)
        except:
            return_val = 'NA'
    else:
        return_val = 'NA'
    return return_val

    # Loop-through-characters version to extract numbers from a string:
    # ================================================================
    # Ensure the string doesn't include 'NA', 'N/A', or 'TBD'
    # See: https://www.w3schools.com/python/gloss_python_regex_metacharacters.asp
    
    # if (re.search(r'N/?A', input_string) != None) or (re.search('TBD', input_string) != None):
    #     return 'NA'
    # else:
    #     # Note: To use with negative numbers, first .strip() whitespace and then check if the leftmost character is a "-".
    #     nums_only = ''
    #     num_decimals = 0
    #     for char in str(input_string):
    #         if char == '.':
    #             num_decimals += 1
    #         if char.isnumeric() or (char == '.' and num_decimals <= 1):
    #             nums_only += char
        
    #     try:
    #         return_val = float(nums_only)
    #     except:
    #         return_val = 'NA'
        
    #     return return_val

# %%
def spec_data(search_text, tag, soup_page):
    '''
    Retrieves data from the CarAndDriver.com spec pages. Returns the data from
    the first element found that matches the search text and tag provided.
    ## Parameters:
    search_text: string or list, required. This is the text displayed 
    on the page by the HTML element. Use a list to search for multiple strings.
    tag: string, required. This is the tag (e.g., 'h3' or 'div') that
    will be used for the search
    soup_page: BeautifulSoup object, required. This is the page to parse.
    ## Return value
    Either the data requested, or else 'NA' if no match is found.
    'NA' is the format used across CarAndDriver.com spec pages, 
    so it can be replaced all at once using pandas after the data is loaded
    to a DataFrame.
    '''
    from bs4 import BeautifulSoup
    import re

    # References:
    # https://pytutorial.com/beautifulsoup-find-by-text
    # https://www.crummy.com/software/BeautifulSoup/bs4/doc/#the-string-argument
    # https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find
    # https://www.crummy.com/software/BeautifulSoup/bs4/doc/#a-regular-expression
    # https://www.kite.com/python/examples/1742/beautifulsoup-find-the-next-element-after-a-tag
    # https://www.kite.com/python/examples/1730/beautifulsoup-find-the-next-sibling-of-a-tag

    if type(search_text) == list:
        string_list = [re.compile(item).pattern for item in search_text]
    else:
        string_list = re.compile(search_text)

    try:
        return_data = soup_page.find(tag, string=string_list).next_sibling.next_element.text
    except:
        # Value not found, None object returned
        return_data = 'NA'
    
    return return_data

# %% [markdown]
# ### Collect information on all trims for each model
# This is the core part of the data collection. It will take approximately 60 minutes to run, and will gather data on about 3,700 trims.
#
# One **model** can have multiple **styles**, and each style can have multiple **trims**. Here's an example:
# 1. Model
#     * Style 1
#         * Trim 1
#         * Trim 2
#     * Style 2
#         * Trim 1
#         * Trim 2
#
# 1. 2021 Honda CR-V
#     * 2021 Honda CR-V Hybrid
#         * 2021 Honda CR-V Hybrid Touring
#         * 2021 Honda CR-V Hybrid Elite
#     * 2021 Honda CR-V
#         * 2021 Honda CR-V LX
#         * 2021 Honda CR-V Special Edition

# %% [markdown]
# The cell below is a test that demonstrates how to retrieve the styles and trim levels for a particular model.

# %%
import json
page = BeautifulSoup(requests.get('https://www.caranddriver.com/honda/cr-v/specs').text, 'html.parser')

form_data = page.find('form', {'id':'specs-filter-form'})
json_data = json.loads(form_data.get('data-submodels'))

print('Style-years for this model: ', len(json_data), '\n', sep='')

for item in enumerate(json_data):
    print(item, '\n')
# Out:
# Style-years for this model: 19
#
# (0, {'id': 'honda_cr-v_honda-cr-v-hybrid_2022', 'name': 'Honda CR-V hybrid', 'chrome_style_ids': [424801, 424802, 424803], 'year': 2022, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/honda_cr-v_honda-cr-v-hybrid_2022-1630871440334.jpg'}}})
#
# (1, {'id': 'honda_cr-v_honda-cr-v_2022', 'name': 'Honda CR-V', 'chrome_style_ids': [424792, 424788, 424793, 424791, 424789, 424785, 424790, 424786, 424787], 'year': 2022, 'is_primary': True, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/honda_cr-v_honda-cr-v_2022-1624473696405.jpg'}}})
#
# (2, {'id': 'honda_cr-v_honda-cr-v_2021', 'name': 'Honda CR-V', 'chrome_style_ids': [418830, 421972, 421971, 418834, 418831, 418835, 418829, 418833, 418832, 418836], 'year': 2021, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/honda_cr-v_honda-cr-v_2021-1607986909173.jpg'}}})
#
# (3, {'id': 'honda_cr-v_honda-cr-v-hybrid_2021', 'name': 'Honda CR-V hybrid', 'chrome_style_ids': [418872, 418873, 418874], 'year': 2021, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': None})
#
# (4, {'id': 'honda_cr-v_honda-cr-v-hybrid_2020', 'name': 'Honda CR-V hybrid', 'chrome_style_ids': [412794, 412795, 412796, 412797], 'year': 2020, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/honda_cr-v_honda-cr-v-hybrid_2020-1588703422046.jpg'}}})
#
# (5, {'id': 'honda_cr-v_honda-cr-v_2020', 'name': 'Honda CR-V', 'chrome_style_ids': [411601, 411605, 411598, 411602, 411604, 411600, 411603, 411599], 'year': 2020, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/honda_cr-v_honda-cr-v_2020-1576254706076.jpg'}}})
#
# (6, {'id': 'honda_cr-v_honda-cr-v_2019', 'name': 'Honda CR-V', 'chrome_style_ids': [404121, 404117, 404118, 404114, 404120, 404116, 404119, 404115], 'year': 2019, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/honda_cr-v_honda-cr-v_2019-1548877379848.jpg'}}})
#
# (7, {'id': 'honda_cr-v_honda-cr-v_2018', 'name': 'Honda CR-V', 'chrome_style_ids': [397490, 397489, 397488, 397487, 397486, 397485, 397484, 397483, 397482, 397481], 'year': 2018, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/media/assets/submodel/8502.jpg'}}})
#
# (8, {'id': 'honda_cr-v_honda-cr-v_2017', 'name': 'Honda CR-V', 'chrome_style_ids': [390234, 390233, 390232, 390231, 390230, 390229, 390228, 390227, 390226, 390225], 'year': 2017, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/media/assets/submodel/7658.jpg'}}})
#
# (9, {'id': 'honda_cr-v_honda-cr-v_2016', 'name': 'Honda CR-V', 'chrome_style_ids': [381654, 381656, 381649, 381648, 381647, 381658, 381652, 381655, 381651, 381653, 381650, 381657], 'year': 2016, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/media/assets/submodel/7419.jpg'}}})
#
# (10, {'id': 'honda_cr-v_honda-cr-v_2015', 'name': 'Honda CR-V', 'chrome_style_ids': [373401, 373394, 373393, 373392, 373397, 373400, 373396, 373398, 373395, 373399], 'year': 2015, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/media/assets/submodel/6476.jpg'}}})
#
# (11, {'id': 'honda_cr-v_honda-cr-v_2014', 'name': 'Honda CR-V', 'chrome_style_ids': [363558, 363557, 363556, 363555, 363554, 363553, 363552, 363551, 363549, 363550], 'year': 2014, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/media/assets/submodel/5798.jpg'}}})
#
# (12, {'id': 'honda_cr-v_honda-cr-v_2013', 'name': 'Honda CR-V', 'chrome_style_ids': [355199, 355197, 355195, 355193, 355191, 355198, 355196, 355194, 355192, 355190], 'year': 2013, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/media/assets/submodel/5321.jpg'}}})
#
# (13, {'id': 'honda_cr-v_honda-cr-v_2012', 'name': 'Honda CR-V', 'chrome_style_ids': [348692, 348694, 348687, 348691, 348689, 348688, 348693, 348602, 348601, 348596], 'year': 2012, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/media/assets/submodel/4377.jpg'}}})
#
# (14, {'id': 'honda_cr-v_honda-cr-v_2011', 'name': 'Honda CR-V', 'chrome_style_ids': [330081, 330080, 329949, 329948, 329947, 329946, 329945, 329944, 329943, 329942], 'year': 2011, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/media/assets/submodel/4076.jpg'}}})
#
# (15, {'id': 'honda_cr-v_honda-cr-v_2010', 'name': 'Honda CR-V', 'chrome_style_ids': [321599, 321598, 321597, 321596, 321595, 321594, 321593, 321592], 'year': 2010, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/media/assets/submodel/3437.jpg'}}})
#
# (16, {'id': 'honda_cr-v_honda-cr-v_2009', 'name': 'Honda CR-V', 'chrome_style_ids': [308104, 308103, 308102, 308101, 308100, 308099, 308098, 308097], 'year': 2009, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/media/assets/submodel/2732.jpg'}}})
#
# (17, {'id': 'honda_cr-v_honda-cr-v_2008', 'name': 'Honda CR-V', 'chrome_style_ids': [293655, 293654, 293653, 293652, 293651, 293650, 293649, 293648], 'year': 2008, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/media/assets/submodel/1739.jpg'}}})
#
# (18, {'id': 'honda_cr-v_honda-cr-v_2007', 'name': 'Honda CR-V', 'chrome_style_ids': [287265, 287264, 287263, 287262, 287261, 287260, 287259, 287258], 'year': 2007, 'is_primary': False, 'state': 'published', 'body_style': 'suv', 'media': {'media_object': {'hips_url': 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/media/assets/submodel/261.jpg'}}})

# %%
# Set the threshold for determining the model's origin: Domestic or Foreign
domestic_content_threshold = 0.50

# Set the start_time variable to track progress and execution time
start_time = time.time()

# Loop through vehicle models
for model_num, (vehicle_model, vehicle_attributes) in enumerate(models.items()):
    # Access the default specs page for the model
    specs_url = vehicle_attributes['URL'] + '/specs'
    response = requests.get(url=specs_url)
    if response.ok == False:
        # Model has no specs page, so skip it
        continue
    
    page = BeautifulSoup(response.text, 'html.parser')

    # Find all available years, styles, and trims for the model.
    # All the style and trim info is contained in a form element 
    # on the page, structured as a list-of-dictionaries where each
    # list item represents one model-style-year (a style for a year
    # for a particular model). Styles can have multiple trims.
    form_data = page.find('form', {'id':'specs-filter-form'})
    style_names = []
    style_ids = []
    body_styles = []
    trim_ids = []
    image_urls = []
    model_years = []

    # The attribute I need from that form element is called data-submodels
    json_data = json.loads(form_data.get('data-submodels'))

    # Save the default selected year, usually the most recent one
    # Option 1: using text from web page
    #   selected_year = int(page.find('select', {'id':'specs-year-select'}).find('option', {'selected':True}).text)
    # Option 2: using the data from the form on the web page
    for model_style_year in json_data:
        if model_style_year['is_primary'] == True:
            selected_year = model_style_year['year']
            break   # exit loop, since default year was found


    # Collect all styles and trims for the selected model year
    for model_style_year in json_data:
        if model_style_year['year'] == selected_year:
            model_years.append(model_style_year['year'])
            style_ids.append(model_style_year['id'])
            style_names.append(model_style_year['name'])
            body_styles.append(model_style_year['body_style'])
            if  model_style_year['media'] == None:
                image_urls.append('')
            else:
                image_urls.append(model_style_year['media']['media_object']['hips_url'])
            trim_ids.append(model_style_year['chrome_style_ids'])

    # Loop through styles (and trims) to collect data
    for style_num, style_id in enumerate(style_ids):
        for trim_id in trim_ids[style_num]:
            if trim_id in vehicle_specs['Trim_ID']:
                continue    # Trim already accounted for, skip to next one
            trim_url = f'{specs_url}/{selected_year}/{style_id}/{trim_id}'
            page = BeautifulSoup(requests.get(url=trim_url).text, 'html.parser')

            # ===========================================================
            # Collect data from page and save to vehicle_specs dictionary
            # ===========================================================

            vehicle_specs['Make'].append(vehicle_attributes['Make']) 
            vehicle_specs['Model'].append(vehicle_model) 
            vehicle_specs['Year'].append(model_years[style_num]) # could also use selected_year or vehicle_attributes['Year']
            vehicle_specs['Style'].append(style_names[style_num])
            
            # To get the trim name, I remove the "not needed" characters
            # from the end of the trim name listed on the specs page
            not_needed_char_count = -1 * len(' Package Includes')
            vehicle_specs['Trim'].append(spec_data('Overview', 'h4', page)[:not_needed_char_count])
            
            vehicle_specs['Trim_ID'].append(trim_id)
            vehicle_specs['Body_style'].append(body_styles[style_num]) 
            vehicle_specs['EPA_class'].append(spec_data('EPA Classification', 'h3', page)) 
            vehicle_specs['Pct_domestic_content'].append(vehicle_attributes['Pct_domestic_content']) 
            
            # vehicle origin (domestic, foreign, or unknown)
            if vehicle_attributes['Pct_domestic_content'] == '':
                vehicle_origin = 'unknown'                
            elif vehicle_attributes['Pct_domestic_content'] >= domestic_content_threshold:
                vehicle_origin = 'domestic'
            else:
                vehicle_origin = 'foreign'
            vehicle_specs['Origin'].append(vehicle_origin) 
            
            vehicle_specs['URL'].append(trim_url) 
            vehicle_specs['Image'].append(image_urls[style_num]) 
            vehicle_specs['Price'].append(numbers_only(page.find('div', {'class':'price'}).text)) 
            vehicle_specs['Drivetrain'].append(spec_data('Drivetrain', 'h3', page)) 
            vehicle_specs['Engine'].append(spec_data('Engine Type and Required Fuel', 'h3', page)) 
            
            # Engine size in liters and in cubic inches
            engine_size = spec_data('Displacement', 'h3', page) 
            engine_size = engine_size.split('/')
            if len(engine_size) == 1:
                # Add 'NA' as a second element if the cubic inches size isn't given
                engine_size.append('NA') 
            vehicle_specs['Engine_size_liters'].append(numbers_only(engine_size[0])) 
            vehicle_specs['Engine_size_inches'].append(numbers_only(engine_size[1])) 
            
            # Horsepower and RPM
            horsepower = spec_data('Maximum Horsepower', 'h3', page) 
            horsepower = horsepower.split(' @ ')
            if len(horsepower) == 1:
                # Add 'NA' as a second element if the RPM wasn't given
                horsepower.append('NA')
            vehicle_specs['Max_horsepower'].append(numbers_only(horsepower[0])) 
            vehicle_specs['RPM_max_hp'].append(numbers_only(horsepower[1])) 
            
            # Torque and RPM
            torque = spec_data('Maximum Torque', 'h3', page) 
            torque = torque.split(' @ ')
            if len(torque) == 1:
                # Add 'NA' as a second element if the RPM wasn't given
                torque.append('NA')
            vehicle_specs['Max_torque'].append(numbers_only(torque[0])) 
            vehicle_specs['RPM_max_torque'].append(numbers_only(torque[1])) 
            
            vehicle_specs['Transmission_type'].append(spec_data('Transmission Description', 'h3', page))
            vehicle_specs['Transmission_gears'].append(spec_data('Number of Transmission Speeds', 'h3', page)) 
            
            # CO2, with years trimmed; e.g., '9.5 (2021)' becomes '9.5'
            co2 = spec_data('CO2 Emissions', 'h3', page)
            if re.search(r' \([0-9]{4}\)', co2) != None:
                co2 = re.sub(r' \([0-9]{4}\)', '', co2)
            vehicle_specs['CO2_emmissions'].append(numbers_only(co2)) 
            
            # MPG data for combined, city, and highway
            mpg = spec_data('EPA Fuel Economy', 'h3', page) 
            
            # Remove parentheses from mpg, as in: '21 (2021) / 20 (2021) / 22 (2021)'
            # Would become '21 / 20 / 22'
            # The RegEx pattern used is re.compile(r' \([0-9]{4}\)')
            # Could also use re.compile(r' \(.*?\)') as a more general solution
            # See: https://blog.finxter.com/python-regex-to-return-string-between-parentheses/
            if re.search(r' \([0-9]{4}\)', mpg) != None:
                mpg = re.sub(r' \([0-9]{4}\)', '', mpg)
            
            if re.search(r'/[ ]*/', mpg) != None:
                # Alternative fuel vehicle, so first MPG data is empty
                mpg = spec_data('EPA Fuel Economy Equivalent', 'h3', page) 
            mpg = mpg.split('/')
            # Ensure that the mpg list has 3 elements:
            while len(mpg) < 3:
                mpg.append('NA')

            vehicle_specs['MPG_combined'].append(numbers_only(mpg[0])) 
            vehicle_specs['MPG_city'].append(numbers_only(mpg[1])) 
            vehicle_specs['MPG_highway'].append(numbers_only(mpg[2])) 
            vehicle_specs['Fuel_capacity_gallons'].append(numbers_only(spec_data('Fuel Capacity', 'h3', page)))

            # Range, combined
            if vehicle_specs['Fuel_capacity_gallons'][-1] != 'NA' and vehicle_specs['MPG_combined'][-1] != 'NA':
                rng_comb = vehicle_specs['Fuel_capacity_gallons'][-1] * vehicle_specs['MPG_combined'][-1]
            else:
                rng_comb = 'NA'
            vehicle_specs['Range_combined'].append(rng_comb)
            
            # Range, city
            if vehicle_specs['Fuel_capacity_gallons'][-1] != 'NA' and vehicle_specs['MPG_city'][-1] != 'NA':
                rng_city = vehicle_specs['Fuel_capacity_gallons'][-1] * vehicle_specs['MPG_city'][-1]
            else:
                rng_city = 'NA'
            vehicle_specs['Range_city'].append(rng_city)
            
            # Range, highway
            if vehicle_specs['Fuel_capacity_gallons'][-1] != 'NA' and vehicle_specs['MPG_highway'][-1] != 'NA':
                rng_hwy = vehicle_specs['Fuel_capacity_gallons'][-1] * vehicle_specs['MPG_highway'][-1]
            else:
                rng_hwy = 'NA'
            vehicle_specs['Range_highway'].append(rng_hwy)

            vehicle_specs['Wheelbase_inches'].append(numbers_only(spec_data('Wheelbase', 'h3', page))) 
            vehicle_specs['Length_inches'].append(numbers_only(spec_data('Length', 'h3', page))) 
            vehicle_specs['Width_inches'].append(numbers_only(spec_data('Width', 'h3', page))) 
            vehicle_specs['Height_inches'].append(numbers_only(spec_data('Height', 'h3', page))) 
            vehicle_specs['Ground_clearance_inches'].append(numbers_only(spec_data('Ground', 'h3', page))) 
            vehicle_specs['Turning_diameter_ft'].append(numbers_only(spec_data('Turning Diameter / Radius, curb to curb', 'h3', page))) 
            vehicle_specs['Front_wheel_size_inches'].append(spec_data('Front Wheel Size', 'h3', page)) 
            vehicle_specs['Rear_wheel_size_inches'].append(spec_data('Rear Wheel Size', 'h3', page)) 
            vehicle_specs['Same_size_wheels'].append(vehicle_specs['Front_wheel_size_inches'][-1] == vehicle_specs['Rear_wheel_size_inches'][-1])
            vehicle_specs['Seating_capacity'].append(spec_data('Passenger / Seating Capacity', 'h3', page)) 
            vehicle_specs['Cabin_volume_cubic_ft'].append(numbers_only(spec_data('Total Passenger Volume', 'h3', page))) 
            
            # Cargo space
            cargo_terms = ['Cargo Space/Area Behind Front Row', 'Cargo Space/Area', 'Trunk Space']
            for c_term in cargo_terms:
                cargo = spec_data(c_term, 'h3', page)
                if cargo != 'NA':
                    break   # exit loop, value found
            vehicle_specs['Cargo_space_cubic_ft'].append(numbers_only(cargo)) 
            
            # Gross Vehicle Weight Rating (GVWR)
            GVWR = page.find('div', string=re.compile('GVWR'))
            if GVWR != None:
                GVWR = GVWR.text.strip()
                GVWR = GVWR.split(' ')
                if GVWR[1] != 'NA' and GVWR[1] != 'TBD':
                    GVWR = GVWR[1]
                else:
                    GVWR = 'NA'
            else:
                GVWR = 'NA'
            GVWR = numbers_only(GVWR)
            vehicle_specs['GVWR_pounds'].append(GVWR) 

            # Curb weight
            curb_weight = spec_data('Base Curb Weight', 'h3', page)
            if curb_weight == 'NA':
                # text not found, try a different search, starts with 'Curb Weight'
                curb_weight = spec_data('^Curb Weight', 'h3', page)
            curb_weight = numbers_only(curb_weight)
            vehicle_specs['Curb_weight_pounds'].append(curb_weight)

            # Payload capacity (GVWR - Curb Weight)
            if GVWR != 'NA' and curb_weight != 'NA':
                payload_cap = GVWR - curb_weight
            else:
                payload_cap = 'NA'
            
            vehicle_specs['Payload_capacity_pounds'].append(payload_cap)
            
            # Towing capacity
            towing_cap = spec_data('Maximum Towing Capacity', 'h3', page)
            if towing_cap != 'NA':
                towing_cap = numbers_only(towing_cap)
            vehicle_specs['Towing_capacity_pounds'].append(towing_cap) 

            # Pause Python for 10ms before going to the next Trim ID page, 
            # as requested in https://www.caranddriver.com/robots.txt
            # See: https://www.kite.com/python/answers/how-to-sleep-for-a-number-of-milliseconds-in-python
            time.sleep(0.01)
    
    # Indicate progress
    
    # See: https://www.kite.com/python/answers/how-to-measure-time-elapsed-in-python
    # Also: https://www.kite.com/python/answers/how-to-convert-seconds-to-hours,-minutes,-and-seconds-in-python
    elapsed_time = time.time() - start_time
    pct_complete = model_num / len(models)
    estimated_seconds_left = (elapsed_time / pct_complete) - elapsed_time
    est_time_left = str(datetime.timedelta(seconds=estimated_seconds_left))
    # See: https://www.kite.com/python/answers/how-to-format-a-number-as-a-percentage-in-python
    print("{:.1%}".format(pct_complete), 'complete', 
          '\nTrims collected:', len(vehicle_specs['Trim_ID']), 
          '\nEst. total trims:', int(len(vehicle_specs['Trim_ID']) / pct_complete), 
          '\nTime elapsed:', str(datetime.timedelta(seconds=elapsed_time)), 
          '\nEstimated time remaining:', est_time_left, 
          '\nMake:', vehicle_attributes['Make'], 
          '\nModel:', vehicle_model, '\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# 6.9% complete
# Trims collected: 127
# Est. total trims: 1830
# Time elapsed: 0:01:56.192487
# Estimated time remaining: 0:25:58.733178
# Make: Audi
# Model: R8
#
# 7.1% complete
# Trims collected: 127
# Est. total trims: 1796
# Time elapsed: 0:01:56.773578
# Estimated time remaining: 0:25:35.356309
# Make: Audi
# Model: S3
#
# 7.2% complete
# Trims collected: 130
# Est. total trims: 1805
# Time elapsed: 0:01:59.662328
# Estimated time remaining: 0:25:42.556198
# Make: Audi
# Model: S4
#
# 7.3% complete
# Trims collected: 136
# Est. total trims: 1855
# Time elapsed: 0:02:04.339366
# Estimated time remaining: 0:26:12.004847
# Make: Audi
# Model: S5
#
# 7.5% complete
# Trims collected: 138
# Est. total trims: 1849
# Time elapsed: 0:02:06.460191
# Estimated time remaining: 0:26:08.550089
# Make: Audi
# Model: S6
#
# 7.6% complete
# Trims collected: 140
# Est. total trims: 1844
# Time elapsed: 0:02:08.274881
# Estimated time remaining: 0:26:01.414932
# Make: Audi
# Model: S7
#
# 7.7% complete
# Trims collected: 140
# Est. total trims: 1812
# Time elapsed: 0:02:09.739661
# Estimated time remaining: 0:25:50.279006
# Make: Audi
# Model: S8
#
# 7.9% complete
# Trims collected: 140
# Est. total trims: 1782
# Time elapsed: 0:02:10.206564
# Estimated time remaining: 0:25:27.757020
# Make: Audi
# Model: SQ5 / SQ5 Sportback
#
# 8.0% complete
# Trims collected: 140
# Est. total trims: 1753
# Time elapsed: 0:02:10.777068
# Estimated time remaining: 0:25:07.152108
# Make: Audi
# Model: Q7
#
# 8.1% complete
# Trims collected: 142
# Est. total trims: 1749
# Time elapsed: 0:02:12.889054
# Estimated time remaining: 0:25:04.647034
# Make: Audi
# Model: SQ7
#
# 8.2% complete
# Trims collected: 144
# Est. total trims: 1746
# Time elapsed: 0:02:15.104728
# Estimated time remaining: 0:25:03.308169
# Make: Audi
# Model: SQ8
#
# 8.4% complete
# Trims collected: 144
# Est. total trims: 1719
# Time elapsed: 0:02:15.684467
# Estimated time remaining: 0:24:44.048859
# Make: Audi
# Model: TT / TTS
#
# 8.5% complete
# Trims collected: 147
# Est. total trims: 1727
# Time elapsed: 0:02:18.205424
# Estimated time remaining: 0:24:46.239866
# Make: Audi
# Model: S5 Sportback
#
# 8.6% complete
# Trims collected: 148
# Est. total trims: 1713
# Time elapsed: 0:02:19.635891
# Estimated time remaining: 0:24:36.755332
# Make: Audi
# Model: TT RS
#
# 8.8% complete
# Trims collected: 153
# Est. total trims: 1744
# Time elapsed: 0:02:24.181818
# Estimated time remaining: 0:24:59.921298
# Make: Audi
# Model: A3 Sportback e-tron
#
# 8.9% complete
# Trims collected: 155
# Est. total trims: 1741
# Time elapsed: 0:02:27.100831
# Estimated time remaining: 0:25:05.620266
# Make: Audi
# Model: RS4
#
# 9.0% complete
# Trims collected: 158
# Est. total trims: 1749
# Time elapsed: 0:02:29.885278
# Estimated time remaining: 0:25:09.714037
# Make: Bentley
# Model: Continental GT
#
# 9.2% complete
# Trims collected: 158
# Est. total trims: 1724
# Time elapsed: 0:02:29.972232
# Estimated time remaining: 0:24:46.867558
# Make: Bentley
# Model: Bentayga
#
# 9.3% complete
# Trims collected: 158
# Est. total trims: 1700
# Time elapsed: 0:02:30.925299
# Estimated time remaining: 0:24:33.115944
# Make: Bentley
# Model: Flying Spur
#
# 9.4% complete
# Trims collected: 159
# Est. total trims: 1687
# Time elapsed: 0:02:32.209942
# Estimated time remaining: 0:24:22.906663
# Make: Bentley
# Model: Mulsanne
#
# 9.6% complete
# Trims collected: 160
# Est. total trims: 1674
# Time elapsed: 0:02:33.298877
# Estimated time remaining: 0:24:11.089372
# Make: Bentley
# Model: Mulsanne Speed
#
# 9.7% complete
# Trims collected: 160
# Est. total trims: 1651
# Time elapsed: 0:02:33.938657
# Estimated time remaining: 0:23:55.373967
# Make: Bentley
# Model: Continental Supersports
#
# 9.8% complete
# Trims collected: 161
# Est. total trims: 1640
# Time elapsed: 0:02:35.115687
# Estimated time remaining: 0:23:44.996112
# Make: Bentley
# Model: Continental GT Speed
#
# 9.9% complete
# Trims collected: 162
# Est. total trims: 1628
# Time elapsed: 0:02:36.247949
# Estimated time remaining: 0:23:34.455114
# Make: Bentley
# Model: Azure
#
# 10.1% complete
# Trims collected: 163
# Est. total trims: 1617
# Time elapsed: 0:02:37.611513
# Estimated time remaining: 0:23:26.222197
# Make: Bentley
# Model: Brooklands
#
# 10.2% complete
# Trims collected: 166
# Est. total trims: 1625
# Time elapsed: 0:02:40.479545
# Estimated time remaining: 0:23:31.397025
# Make: Bentley
# Model: Arnage
#
# 10.5% complete
# Trims collected: 174
# Est. total trims: 1661
# Time elapsed: 0:02:46.315856
# Estimated time remaining: 0:23:42.000573
# Make: BMW
# Model: 2-series
#
# 10.6% complete
# Trims collected: 177
# Est. total trims: 1669
# Time elapsed: 0:02:49.253783
# Estimated time remaining: 0:23:47.164619
# Make: BMW
# Model: BMW 2-Series Gran Coupe
#
# 10.7% complete
# Trims collected: 189
# Est. total trims: 1760
# Time elapsed: 0:02:59.087358
# Estimated time remaining: 0:24:49.482658
# Make: BMW
# Model: 3-Series
#
# 10.9% complete
# Trims collected: 197
# Est. total trims: 1813
# Time elapsed: 0:03:05.340451
# Estimated time remaining: 0:25:20.684903
# Make: BMW
# Model: 4-series
#
# 11.0% complete
# Trims collected: 201
# Est. total trims: 1828
# Time elapsed: 0:03:07.697137
# Estimated time remaining: 0:25:19.453015
# Make: BMW
# Model: 4-Series Gran Coupe
#
# 11.1% complete
# Trims collected: 207
# Est. total trims: 1860
# Time elapsed: 0:03:13.055482
# Estimated time remaining: 0:25:42.172616
# Make: BMW
# Model: 7-Series
#
# 11.3% complete
# Trims collected: 213
# Est. total trims: 1892
# Time elapsed: 0:03:17.944335
# Estimated time remaining: 0:26:00.537897
# Make: BMW
# Model: 8-Series
#
# 11.4% complete
# Trims collected: 217
# Est. total trims: 1905
# Time elapsed: 0:03:21.623123
# Estimated time remaining: 0:26:08.952351
# Make: BMW
# Model: 8-Series Gran Coupe
#
# 11.8% complete
# Trims collected: 220
# Est. total trims: 1867
# Time elapsed: 0:03:24.298103
# Estimated time remaining: 0:25:29.965796
# Make: BMW
# Model: M3
#
# 11.9% complete
# Trims collected: 222
# Est. total trims: 1863
# Time elapsed: 0:03:26.202969
# Estimated time remaining: 0:25:24.995583
# Make: BMW
# Model: M4
#
# 12.0% complete
# Trims collected: 223
# Est. total trims: 1851
# Time elapsed: 0:03:27.424399
# Estimated time remaining: 0:25:15.099957
# Make: BMW
# Model: M5
#
# 12.2% complete
# Trims collected: 225
# Est. total trims: 1848
# Time elapsed: 0:03:29.630298
# Estimated time remaining: 0:25:12.493873
# Make: BMW
# Model: M8
#
# 12.3% complete
# Trims collected: 226
# Est. total trims: 1836
# Time elapsed: 0:03:31.003495
# Estimated time remaining: 0:25:03.961083
# Make: BMW
# Model: M8 Gran Coupe
#
# 12.4% complete
# Trims collected: 226
# Est. total trims: 1817
# Time elapsed: 0:03:31.091456
# Estimated time remaining: 0:24:46.528251
# Make: BMW
# Model: X1
#
# 12.6% complete
# Trims collected: 229
# Est. total trims: 1822
# Time elapsed: 0:03:33.209416
# Estimated time remaining: 0:24:43.582186
# Make: BMW
# Model: X2
#
# 12.7% complete
# Trims collected: 234
# Est. total trims: 1843
# Time elapsed: 0:03:36.643962
# Estimated time remaining: 0:24:49.706422
# Make: BMW
# Model: X3
#
# 12.8% complete
# Trims collected: 235
# Est. total trims: 1832
# Time elapsed: 0:03:37.768724
# Estimated time remaining: 0:24:39.938469
# Make: BMW
# Model: X3 M
#
# 13.0% complete
# Trims collected: 237
# Est. total trims: 1828
# Time elapsed: 0:03:39.231817
# Estimated time remaining: 0:24:32.617764
# Make: BMW
# Model: X4
#
# 13.1% complete
# Trims collected: 238
# Est. total trims: 1818
# Time elapsed: 0:03:40.604574
# Estimated time remaining: 0:24:24.814374
# Make: BMW
# Model: X4 M
#
# 13.2% complete
# Trims collected: 242
# Est. total trims: 1830
# Time elapsed: 0:03:45.580361
# Estimated time remaining: 0:24:40.789892
# Make: BMW
# Model: X5
#
# 13.4% complete
# Trims collected: 243
# Est. total trims: 1820
# Time elapsed: 0:03:46.687226
# Estimated time remaining: 0:24:31.244547
# Make: BMW
# Model: X5 M
#
# 13.5% complete
# Trims collected: 245
# Est. total trims: 1817
# Time elapsed: 0:03:48.497289
# Estimated time remaining: 0:24:26.375806
# Make: BMW
# Model: X6
#
# 13.6% complete
# Trims collected: 246
# Est. total trims: 1807
# Time elapsed: 0:03:49.170988
# Estimated time remaining: 0:24:14.354346
# Make: BMW
# Model: X6 M
#
# 13.7% complete
# Trims collected: 249
# Est. total trims: 1811
# Time elapsed: 0:03:51.700644
# Estimated time remaining: 0:24:14.197375
# Make: BMW
# Model: X7
#
# 14.0% complete
# Trims collected: 251
# Est. total trims: 1792
# Time elapsed: 0:03:53.233007
# Estimated time remaining: 0:23:52.094258
# Make: BMW
# Model: Z4
#
# 14.1% complete
# Trims collected: 258
# Est. total trims: 1825
# Time elapsed: 0:03:58.921765
# Estimated time remaining: 0:24:11.228501
# Make: BMW
# Model: 5-Series
#
# 14.3% complete
# Trims collected: 259
# Est. total trims: 1815
# Time elapsed: 0:03:59.729453
# Estimated time remaining: 0:24:00.576068
# Make: BMW
# Model: M2
#
# 14.4% complete
# Trims collected: 263
# Est. total trims: 1826
# Time elapsed: 0:04:03.329272
# Estimated time remaining: 0:24:06.703124
# Make: BMW
# Model: i3
#
# 14.5% complete
# Trims collected: 265
# Est. total trims: 1823
# Time elapsed: 0:04:05.177452
# Estimated time remaining: 0:24:02.350238
# Make: BMW
# Model: i8
#
# 14.7% complete
# Trims collected: 266
# Est. total trims: 1814
# Time elapsed: 0:04:06.308897
# Estimated time remaining: 0:23:53.869651
# Make: BMW
# Model: 3-series Wagon
#
# 14.8% complete
# Trims collected: 271
# Est. total trims: 1832
# Time elapsed: 0:04:09.999609
# Estimated time remaining: 0:24:00.263233
# Make: BMW
# Model: 6-series Gran Coupe
#
# 14.9% complete
# Trims collected: 272
# Est. total trims: 1822
# Time elapsed: 0:04:11.202258
# Estimated time remaining: 0:23:52.293576
# Make: BMW
# Model: 6-series Gran Turismo
#
# 15.1% complete
# Trims collected: 273
# Est. total trims: 1813
# Time elapsed: 0:04:12.422899
# Estimated time remaining: 0:23:44.543144
# Make: BMW
# Model: M6 Gran Coupe
#
# 15.2% complete
# Trims collected: 277
# Est. total trims: 1824
# Time elapsed: 0:04:15.617627
# Estimated time remaining: 0:23:47.932950
# Make: BMW
# Model: 6-series
#
# 15.3% complete
# Trims collected: 278
# Est. total trims: 1815
# Time elapsed: 0:04:16.325761
# Estimated time remaining: 0:23:37.459549
# Make: BMW
# Model: M6
#
# 15.4% complete
# Trims collected: 284
# Est. total trims: 1838
# Time elapsed: 0:04:21.213918
# Estimated time remaining: 0:23:50.035520
# Make: BMW
# Model: 1-series
#
# 15.6% complete
# Trims collected: 288
# Est. total trims: 1849
# Time elapsed: 0:04:24.488698
# Estimated time remaining: 0:23:53.573192
# Make: BMW
# Model: Taycan Cross Turismo
#
# 16.4% complete
# Trims collected: 294
# Est. total trims: 1796
# Time elapsed: 0:04:30.803090
# Estimated time remaining: 0:23:04.345398
# Make: Buick
# Model: Enclave
#
# 16.5% complete
# Trims collected: 296
# Est. total trims: 1794
# Time elapsed: 0:04:32.831029
# Estimated time remaining: 0:23:01.477750
# Make: Buick
# Model: Encore
#
# 16.6% complete
# Trims collected: 302
# Est. total trims: 1816
# Time elapsed: 0:04:37.951163
# Estimated time remaining: 0:23:14.133000
# Make: Buick
# Model: Encore GX
#
# 16.8% complete
# Trims collected: 308
# Est. total trims: 1838
# Time elapsed: 0:04:42.539392
# Estimated time remaining: 0:23:23.867603
# Make: Buick
# Model: Envision
#
# 16.9% complete
# Trims collected: 308
# Est. total trims: 1824
# Time elapsed: 0:04:43.197567
# Estimated time remaining: 0:23:14.034538
# Make: Buick
# Model: Regal GS
#
# 17.0% complete
# Trims collected: 314
# Est. total trims: 1845
# Time elapsed: 0:04:48.480306
# Estimated time remaining: 0:23:26.896260
# Make: Buick
# Model: Regal Sportback
#
# 17.1% complete
# Trims collected: 317
# Est. total trims: 1848
# Time elapsed: 0:04:51.122363
# Estimated time remaining: 0:23:26.721035
# Make: Buick
# Model: Regal TourX
#
# 17.3% complete
# Trims collected: 326
# Est. total trims: 1886
# Time elapsed: 0:04:58.344161
# Estimated time remaining: 0:23:48.435681
# Make: Buick
# Model: LaCrosse
#
# 17.4% complete
# Trims collected: 329
# Est. total trims: 1889
# Time elapsed: 0:05:01.275935
# Estimated time remaining: 0:23:49.361769
# Make: Buick
# Model: Cascada
#
# 17.5% complete
# Trims collected: 336
# Est. total trims: 1915
# Time elapsed: 0:05:07.449029
# Estimated time remaining: 0:24:05.469315
# Make: Buick
# Model: Regal
#
# 17.7% complete
# Trims collected: 339
# Est. total trims: 1918
# Time elapsed: 0:05:10.473345
# Estimated time remaining: 0:24:06.575805
# Make: Buick
# Model: Verano
#
# 17.8% complete
# Trims collected: 343
# Est. total trims: 1926
# Time elapsed: 0:05:13.943146
# Estimated time remaining: 0:24:09.678646
# Make: Buick
# Model: Lucerne
#
# 18.3% complete
# Trims collected: 347
# Est. total trims: 1893
# Time elapsed: 0:05:17.686790
# Estimated time remaining: 0:23:35.975408
# Make: Cadillac
# Model: CT4
#
# 18.5% complete
# Trims collected: 348
# Est. total trims: 1885
# Time elapsed: 0:05:19.051511
# Estimated time remaining: 0:23:29.709867
# Make: Cadillac
# Model: CT4-V Blackwing
#
# 18.6% complete
# Trims collected: 352
# Est. total trims: 1893
# Time elapsed: 0:05:22.481522
# Estimated time remaining: 0:23:32.559907
# Make: Cadillac
# Model: CT5
#
# 18.7% complete
# Trims collected: 353
# Est. total trims: 1885
# Time elapsed: 0:05:23.154055
# Estimated time remaining: 0:23:23.347330
# Make: Cadillac
# Model: CT5-V Blackwing
#
# 18.8% complete
# Trims collected: 373
# Est. total trims: 1978
# Time elapsed: 0:05:38.927055
# Estimated time remaining: 0:24:19.269266
# Make: Cadillac
# Model: Escalade
#
# 19.0% complete
# Trims collected: 379
# Est. total trims: 1996
# Time elapsed: 0:05:43.648757
# Estimated time remaining: 0:24:27.024693
# Make: Cadillac
# Model: XT4
#
# 19.1% complete
# Trims collected: 384
# Est. total trims: 2009
# Time elapsed: 0:05:47.143325
# Estimated time remaining: 0:24:29.414896
# Make: Cadillac
# Model: XT5
#
# 19.2% complete
# Trims collected: 389
# Est. total trims: 2021
# Time elapsed: 0:05:51.036324
# Estimated time remaining: 0:24:33.397361
# Make: Cadillac
# Model: XT6
#
# 19.4% complete
# Trims collected: 393
# Est. total trims: 2028
# Time elapsed: 0:05:54.613495
# Estimated time remaining: 0:24:35.958872
# Make: Cadillac
# Model: CT6
#
# 19.5% complete
# Trims collected: 400
# Est. total trims: 2051
# Time elapsed: 0:05:59.964694
# Estimated time remaining: 0:24:45.760313
# Make: Cadillac
# Model: ATS
#
# 19.6% complete
# Trims collected: 401
# Est. total trims: 2042
# Time elapsed: 0:06:01.046351
# Estimated time remaining: 0:24:37.883065
# Make: Cadillac
# Model: ATS-V
#
# 19.8% complete
# Trims collected: 411
# Est. total trims: 2079
# Time elapsed: 0:06:08.102822
# Estimated time remaining: 0:24:54.351191
# Make: Cadillac
# Model: CTS
#
# 19.9% complete
# Trims collected: 412
# Est. total trims: 2070
# Time elapsed: 0:06:08.888343
# Estimated time remaining: 0:24:45.260960
# Make: Cadillac
# Model: CTS-V
#
# 20.0% complete
# Trims collected: 420
# Est. total trims: 2097
# Time elapsed: 0:06:15.179285
# Estimated time remaining: 0:24:58.264986
# Make: Cadillac
# Model: XTS
#
# 20.2% complete
# Trims collected: 421
# Est. total trims: 2088
# Time elapsed: 0:06:16.374594
# Estimated time remaining: 0:24:50.834430
# Make: Cadillac
# Model: ELR
#
# 20.3% complete
# Trims collected: 428
# Est. total trims: 2109
# Time elapsed: 0:06:21.686195
# Estimated time remaining: 0:24:59.657372
# Make: Cadillac
# Model: SRX
#
# 20.4% complete
# Trims collected: 431
# Est. total trims: 2110
# Time elapsed: 0:06:24.055054
# Estimated time remaining: 0:24:56.829953
# Make: Cadillac
# Model: Escalade EXT
#
# 20.5% complete
# Trims collected: 436
# Est. total trims: 2121
# Time elapsed: 0:06:27.619219
# Estimated time remaining: 0:24:58.629718
# Make: Cadillac
# Model: DTS
#
# 20.7% complete
# Trims collected: 441
# Est. total trims: 2132
# Time elapsed: 0:06:31.851426
# Estimated time remaining: 0:25:02.923824
# Make: Cadillac
# Model: STS
#
# 20.8% complete
# Trims collected: 443
# Est. total trims: 2128
# Time elapsed: 0:06:33.810309
# Estimated time remaining: 0:24:58.460609
# Make: Cadillac
# Model: XLR
#
# 21.1% complete
# Trims collected: 451
# Est. total trims: 2140
# Time elapsed: 0:06:39.885583
# Estimated time remaining: 0:24:57.708114
# Make: Chevrolet
# Model: Blazer
#
# 21.2% complete
# Trims collected: 453
# Est. total trims: 2136
# Time elapsed: 0:06:42.052661
# Estimated time remaining: 0:24:54.047542
# Make: Chevrolet
# Model: Bolt EUV
#
# 21.3% complete
# Trims collected: 455
# Est. total trims: 2132
# Time elapsed: 0:06:42.892035
# Estimated time remaining: 0:24:45.509896
# Make: Chevrolet
# Model: Bolt EV
#
# 21.5% complete
# Trims collected: 473
# Est. total trims: 2203
# Time elapsed: 0:06:55.981919
# Estimated time remaining: 0:25:21.885070
# Make: Chevrolet
# Model: Colorado
#
# 21.6% complete
# Trims collected: 479
# Est. total trims: 2217
# Time elapsed: 0:07:01.692159
# Estimated time remaining: 0:25:30.870322
# Make: Chevrolet
# Model: Corvette
#
# 21.7% complete
# Trims collected: 479
# Est. total trims: 2204
# Time elapsed: 0:07:01.776564
# Estimated time remaining: 0:25:19.411960
# Make: Chevrolet
# Model: Corvette Z06
#
# 21.9% complete
# Trims collected: 486
# Est. total trims: 2223
# Time elapsed: 0:07:07.145776
# Estimated time remaining: 0:25:26.982205
# Make: Chevrolet
# Model: Equinox
#
# 22.0% complete
# Trims collected: 520
# Est. total trims: 2364
# Time elapsed: 0:07:32.521437
# Estimated time remaining: 0:26:45.373669
# Make: Chevrolet
# Model: Silverado 1500
#
# 22.3% complete
# Trims collected: 591
# Est. total trims: 2656
# Time elapsed: 0:08:27.843995
# Estimated time remaining: 0:29:34.466664
# Make: Chevrolet
# Model: Silverado HD
#
# 22.4% complete
# Trims collected: 602
# Est. total trims: 2689
# Time elapsed: 0:08:36.549938
# Estimated time remaining: 0:29:51.310605
# Make: Chevrolet
# Model: Suburban
#
# 22.5% complete
# Trims collected: 613
# Est. total trims: 2722
# Time elapsed: 0:08:44.989086
# Estimated time remaining: 0:30:06.939180
# Make: Chevrolet
# Model: Tahoe
#
# 22.6% complete
# Trims collected: 621
# Est. total trims: 2742
# Time elapsed: 0:08:50.689892
# Estimated time remaining: 0:30:12.934833
# Make: Chevrolet
# Model: Trailblazer
#
# 22.8% complete
# Trims collected: 625
# Est. total trims: 2744
# Time elapsed: 0:08:53.997516
# Estimated time remaining: 0:30:10.681234
# Make: Chevrolet
# Model: Trax
#
# 22.9% complete
# Trims collected: 637
# Est. total trims: 2780
# Time elapsed: 0:09:02.216694
# Estimated time remaining: 0:30:24.946474
# Make: Chevrolet
# Model: Traverse
#
# 23.0% complete
# Trims collected: 650
# Est. total trims: 2821
# Time elapsed: 0:09:13.085423
# Estimated time remaining: 0:30:47.808116
# Make: Chevrolet
# Model: Camaro
#
# 23.2% complete
# Trims collected: 652
# Est. total trims: 2814
# Time elapsed: 0:09:15.086287
# Estimated time remaining: 0:30:40.879380
# Make: Chevrolet
# Model: Camaro ZL1
#
# 23.3% complete
# Trims collected: 667
# Est. total trims: 2862
# Time elapsed: 0:09:28.205570
# Estimated time remaining: 0:31:10.609348
# Make: Chevrolet
# Model: Express
#
# 23.4% complete
# Trims collected: 672
# Est. total trims: 2868
# Time elapsed: 0:09:32.481769
# Estimated time remaining: 0:31:10.959972
# Make: Chevrolet
# Model: Malibu
#
# 23.6% complete
# Trims collected: 680
# Est. total trims: 2886
# Time elapsed: 0:09:39.179811
# Estimated time remaining: 0:31:19.116720
# Make: Chevrolet
# Model: Spark
#
# 23.7% complete
# Trims collected: 685
# Est. total trims: 2891
# Time elapsed: 0:09:43.158387
# Estimated time remaining: 0:31:18.349944
# Make: Chevrolet
# Model: Sonic
#
# 23.8% complete
# Trims collected: 689
# Est. total trims: 2892
# Time elapsed: 0:09:46.889316
# Estimated time remaining: 0:31:16.755946
# Make: Chevrolet
# Model: Corvette ZR1
#
# 24.0% complete
# Trims collected: 698
# Est. total trims: 2914
# Time elapsed: 0:09:53.905378
# Estimated time remaining: 0:31:25.568442
# Make: Chevrolet
# Model: Cruze
#
# 24.1% complete
# Trims collected: 701
# Est. total trims: 2910
# Time elapsed: 0:09:56.208641
# Estimated time remaining: 0:31:19.353324
# Make: Chevrolet
# Model: Impala
#
# 24.2% complete
# Trims collected: 703
# Est. total trims: 2903
# Time elapsed: 0:09:58.351928
# Estimated time remaining: 0:31:12.679817
# Make: Chevrolet
# Model: Volt
#
# 24.3% complete
# Trims collected: 705
# Est. total trims: 2895
# Time elapsed: 0:10:00.770587
# Estimated time remaining: 0:31:06.910748
# Make: Chevrolet
# Model: City Express
#
# 24.5% complete
# Trims collected: 705
# Est. total trims: 2880
# Time elapsed: 0:10:01.288893
# Estimated time remaining: 0:30:55.313856
# Make: Chevrolet
# Model: Silverado 2500HD/3500HD
#
# 24.6% complete
# Trims collected: 706
# Est. total trims: 2869
# Time elapsed: 0:10:03.342485
# Estimated time remaining: 0:30:48.538679
# Make: Chevrolet
# Model: SS
#
# 24.7% complete
# Trims collected: 708
# Est. total trims: 2861
# Time elapsed: 0:10:05.134845
# Estimated time remaining: 0:30:41.018709
# Make: Chevrolet
# Model: Spark EV
#
# 24.9% complete
# Trims collected: 709
# Est. total trims: 2850
# Time elapsed: 0:10:06.188067
# Estimated time remaining: 0:30:31.326054
# Make: Chevrolet
# Model: Camaro Z/28
#
# 25.0% complete
# Trims collected: 715
# Est. total trims: 2860
# Time elapsed: 0:10:11.331580
# Estimated time remaining: 0:30:33.994740
# Make: Chevrolet
# Model: Avalanche
#
# 25.1% complete
# Trims collected: 721
# Est. total trims: 2868
# Time elapsed: 0:10:16.166855
# Estimated time remaining: 0:30:35.663756
# Make: Chevrolet
# Model: Aveo
#
# 25.3% complete
# Trims collected: 725
# Est. total trims: 2869
# Time elapsed: 0:10:19.416664
# Estimated time remaining: 0:30:32.574689
# Make: Chevrolet
# Model: HHR
#
# 25.4% complete
# Trims collected: 734
# Est. total trims: 2890
# Time elapsed: 0:10:27.074633
# Estimated time remaining: 0:30:42.435776
# Make: Chevrolet
# Model: Cobalt
#
# 25.5% complete
# Trims collected: 741
# Est. total trims: 2903
# Time elapsed: 0:10:32.523586
# Estimated time remaining: 0:30:45.671388
# Make: Chrysler
# Model: 300
#
# 25.7% complete
# Trims collected: 751
# Est. total trims: 2927
# Time elapsed: 0:10:39.585305
# Estimated time remaining: 0:30:53.492110
# Make: Chrysler
# Model: Pacifica
#
# 25.8% complete
# Trims collected: 751
# Est. total trims: 2912
# Time elapsed: 0:10:40.048843
# Estimated time remaining: 0:30:42.171034
# Make: Chrysler
# Model: Voyager
#
# 25.9% complete
# Trims collected: 760
# Est. total trims: 2932
# Time elapsed: 0:10:47.057348
# Estimated time remaining: 0:30:49.668985
# Make: Chrysler
# Model: 200
#
# 26.0% complete
# Trims collected: 767
# Est. total trims: 2944
# Time elapsed: 0:10:52.541923
# Estimated time remaining: 0:30:52.694404
# Make: Chrysler
# Model: Town & Country
#
# 26.2% complete
# Trims collected: 769
# Est. total trims: 2937
# Time elapsed: 0:10:53.848789
# Estimated time remaining: 0:30:43.853586
# Make: Chrysler
# Model: 300 SRT
#
# 26.3% complete
# Trims collected: 770
# Est. total trims: 2926
# Time elapsed: 0:10:55.163799
# Estimated time remaining: 0:30:35.110540
# Make: Chrysler
# Model: PT Cruiser
#
# 26.4% complete
# Trims collected: 775
# Est. total trims: 2931
# Time elapsed: 0:10:59.722310
# Estimated time remaining: 0:30:35.465040
# Make: Chrysler
# Model: Sebring
#
# 26.6% complete
# Trims collected: 778
# Est. total trims: 2928
# Time elapsed: 0:11:02.296217
# Estimated time remaining: 0:30:30.286590
# Make: Chrysler
# Model: Aspen
#
# 26.8% complete
# Trims collected: 785
# Est. total trims: 2925
# Time elapsed: 0:11:06.832340
# Estimated time remaining: 0:30:18.337942
# Make: Dodge
# Model: Challenger
#
# 27.0% complete
# Trims collected: 790
# Est. total trims: 2929
# Time elapsed: 0:11:10.641873
# Estimated time remaining: 0:30:16.593035
# Make: Dodge
# Model: Challenger SRT Hellcat
#
# 27.1% complete
# Trims collected: 797
# Est. total trims: 2941
# Time elapsed: 0:11:16.134040
# Estimated time remaining: 0:30:19.355846
# Make: Dodge
# Model: Charger
#
# 27.2% complete
# Trims collected: 799
# Est. total trims: 2934
# Time elapsed: 0:11:18.037077
# Estimated time remaining: 0:30:12.445263
# Make: Dodge
# Model: Charger SRT Hellcat
#
# 27.4% complete
# Trims collected: 811
# Est. total trims: 2964
# Time elapsed: 0:11:27.268452
# Estimated time remaining: 0:30:25.043018
# Make: Dodge
# Model: Durango
#
# 27.5% complete
# Trims collected: 812
# Est. total trims: 2954
# Time elapsed: 0:11:28.565287
# Estimated time remaining: 0:30:16.500804
# Make: Dodge
# Model: Durango SRT
#
# 27.6% complete
# Trims collected: 813
# Est. total trims: 2943
# Time elapsed: 0:11:29.701782
# Estimated time remaining: 0:30:07.607041
# Make: Dodge
# Model: Durango SRT Hellcat
#
# 27.7% complete
# Trims collected: 816
# Est. total trims: 2940
# Time elapsed: 0:11:32.731681
# Estimated time remaining: 0:30:03.716452
# Make: Dodge
# Model: Grand Caravan
#
# 27.9% complete
# Trims collected: 818
# Est. total trims: 2934
# Time elapsed: 0:11:34.132989
# Estimated time remaining: 0:29:55.621018
# Make: Dodge
# Model: Journey
#
# 28.0% complete
# Trims collected: 819
# Est. total trims: 2923
# Time elapsed: 0:11:35.361960
# Estimated time remaining: 0:29:47.145225
# Make: Dodge
# Model: Challenger SRT Demon
#
# 28.1% complete
# Trims collected: 819
# Est. total trims: 2910
# Time elapsed: 0:11:35.891705
# Estimated time remaining: 0:29:36.951378
# Make: Dodge
# Model: Challenger SRT 392 / SRT Hellcat
#
# 28.3% complete
# Trims collected: 824
# Est. total trims: 2914
# Time elapsed: 0:11:40.024099
# Estimated time remaining: 0:29:35.987066
# Make: Dodge
# Model: Viper
#
# 28.4% complete
# Trims collected: 835
# Est. total trims: 2939
# Time elapsed: 0:11:48.455554
# Estimated time remaining: 0:29:45.830358
# Make: Dodge
# Model: Dart
#
# 28.5% complete
# Trims collected: 838
# Est. total trims: 2936
# Time elapsed: 0:11:51.478688
# Estimated time remaining: 0:29:41.960385
# Make: Dodge
# Model: Avenger
#
# 28.7% complete
# Trims collected: 841
# Est. total trims: 2933
# Time elapsed: 0:11:54.198391
# Estimated time remaining: 0:29:37.343027
# Make: Dodge
# Model: Caliber
#
# 28.8% complete
# Trims collected: 847
# Est. total trims: 2941
# Time elapsed: 0:12:03.578077
# Estimated time remaining: 0:29:49.211245
# Make: Dodge
# Model: Magnum
#
# 28.9% complete
# Trims collected: 853
# Est. total trims: 2948
# Time elapsed: 0:12:08.753370
# Estimated time remaining: 0:29:50.556923
# Make: Dodge
# Model: Nitro
#
# 29.3% complete
# Trims collected: 853
# Est. total trims: 2909
# Time elapsed: 0:12:09.897167
# Estimated time remaining: 0:29:19.573528
# Make: Ferrari
# Model: 812 Superfast / GTS
#
# 29.5% complete
# Trims collected: 855
# Est. total trims: 2903
# Time elapsed: 0:12:11.827752
# Estimated time remaining: 0:29:13.134036
# Make: Ferrari
# Model: F8 Tributo / Spider
#
# 29.6% complete
# Trims collected: 856
# Est. total trims: 2893
# Time elapsed: 0:12:13.098161
# Estimated time remaining: 0:29:05.162879
# Make: Ferrari
# Model: Portofino M
#
# 30.0% complete
# Trims collected: 856
# Est. total trims: 2855
# Time elapsed: 0:12:14.428239
# Estimated time remaining: 0:28:35.803964
# Make: Ferrari
# Model: 488 Pista
#
# 30.1% complete
# Trims collected: 856
# Est. total trims: 2843
# Time elapsed: 0:12:15.215426
# Estimated time remaining: 0:28:26.978423
# Make: Ferrari
# Model: GTC4Lusso
#
# 30.2% complete
# Trims collected: 857
# Est. total trims: 2834
# Time elapsed: 0:12:16.827045
# Estimated time remaining: 0:28:20.124741
# Make: Ferrari
# Model: California T
#
# 30.4% complete
# Trims collected: 858
# Est. total trims: 2825
# Time elapsed: 0:12:18.159406
# Estimated time remaining: 0:28:12.675879
# Make: Ferrari
# Model: F12berlinetta
#
# 30.5% complete
# Trims collected: 859
# Est. total trims: 2816
# Time elapsed: 0:12:19.432977
# Estimated time remaining: 0:28:05.145540
# Make: Ferrari
# Model: FF
#
# 30.6% complete
# Trims collected: 860
# Est. total trims: 2807
# Time elapsed: 0:12:20.249430
# Estimated time remaining: 0:27:56.633324
# Make: Ferrari
# Model: LaFerrari
#
# 30.8% complete
# Trims collected: 860
# Est. total trims: 2795
# Time elapsed: 0:12:20.774661
# Estimated time remaining: 0:27:47.531046
# Make: Ferrari
# Model: 599GTB Fiorano
#
# 30.9% complete
# Trims collected: 860
# Est. total trims: 2784
# Time elapsed: 0:12:21.370556
# Estimated time remaining: 0:27:38.659549
# Make: Ferrari
# Model: F430
#
# 31.0% complete
# Trims collected: 860
# Est. total trims: 2772
# Time elapsed: 0:12:22.002578
# Estimated time remaining: 0:27:29.938223
# Make: Fiat
# Model: 500X
#
# 31.2% complete
# Trims collected: 860
# Est. total trims: 2760
# Time elapsed: 0:12:22.684907
# Estimated time remaining: 0:27:21.396054
# Make: Fiat
# Model: 124 Spider
#
# 31.3% complete
# Trims collected: 865
# Est. total trims: 2765
# Time elapsed: 0:12:27.459251
# Estimated time remaining: 0:27:21.908396
# Make: Fiat
# Model: 500L
#
# 31.4% complete
# Trims collected: 869
# Est. total trims: 2766
# Time elapsed: 0:12:30.710262
# Estimated time remaining: 0:27:19.050738
# Make: Fiat
# Model: 500
#
# 31.5% complete
# Trims collected: 871
# Est. total trims: 2761
# Time elapsed: 0:12:32.234344
# Estimated time remaining: 0:27:12.442167
# Make: Fiat
# Model: 500 Abarth
#
# 31.7% complete
# Trims collected: 872
# Est. total trims: 2752
# Time elapsed: 0:12:33.437116
# Estimated time remaining: 0:27:05.182540
# Make: Fiat
# Model: 500e
#
# 31.9% complete
# Trims collected: 872
# Est. total trims: 2730
# Time elapsed: 0:12:34.733698
# Estimated time remaining: 0:26:48.448864
# Make: Fisker
# Model: Karma
#
# 32.3% complete
# Trims collected: 884
# Est. total trims: 2734
# Time elapsed: 0:12:43.473879
# Estimated time remaining: 0:26:38.040467
# Make: Ford
# Model: Ranger
#
# 32.6% complete
# Trims collected: 904
# Est. total trims: 2773
# Time elapsed: 0:12:58.799924
# Estimated time remaining: 0:26:50.770928
# Make: Ford
# Model: Bronco
#
# 32.7% complete
# Trims collected: 908
# Est. total trims: 2774
# Time elapsed: 0:13:01.097223
# Estimated time remaining: 0:26:45.935891
# Make: Ford
# Model: Bronco Sport
#
# 33.0% complete
# Trims collected: 913
# Est. total trims: 2767
# Time elapsed: 0:13:04.351282
# Estimated time remaining: 0:26:33.602605
# Make: Ford
# Model: Edge
#
# 33.1% complete
# Trims collected: 926
# Est. total trims: 2796
# Time elapsed: 0:13:13.549566
# Estimated time remaining: 0:26:42.781930
# Make: Ford
# Model: Escape
#
# 33.2% complete
# Trims collected: 926
# Est. total trims: 2785
# Time elapsed: 0:13:14.195712
# Estimated time remaining: 0:26:34.644933
# Make: Ford
# Model: Expedition
#
# 33.4% complete
# Trims collected: 941
# Est. total trims: 2819
# Time elapsed: 0:13:25.647444
# Estimated time remaining: 0:26:48.135487
# Make: Ford
# Model: Explorer
#
# 33.6% complete
# Trims collected: 947
# Est. total trims: 2815
# Time elapsed: 0:13:29.953654
# Estimated time remaining: 0:26:37.846313
# Make: Ford
# Model: Maverick
#
# 33.8% complete
# Trims collected: 947
# Est. total trims: 2804
# Time elapsed: 0:13:30.066211
# Estimated time remaining: 0:26:28.734506
# Make: Ford
# Model: Mustang
#
# 33.9% complete
# Trims collected: 954
# Est. total trims: 2814
# Time elapsed: 0:13:35.423637
# Estimated time remaining: 0:26:29.918675
# Make: Ford
# Model: Mustang Mach-E
#
# 34.0% complete
# Trims collected: 1130
# Est. total trims: 3320
# Time elapsed: 0:15:47.266913
# Estimated time remaining: 0:30:36.240478
# Make: Ford
# Model: Super Duty
#
# 34.2% complete
# Trims collected: 1137
# Est. total trims: 3328
# Time elapsed: 0:15:53.423888
# Estimated time remaining: 0:30:37.441440
# Make: Ford
# Model: EcoSport
#
# 34.3% complete
# Trims collected: 1180
# Est. total trims: 3440
# Time elapsed: 0:16:25.958935
# Estimated time remaining: 0:31:29.127426
# Make: Ford
# Model: F-150
#
# 34.4% complete
# Trims collected: 1180
# Est. total trims: 3427
# Time elapsed: 0:16:26.443541
# Estimated time remaining: 0:31:19.118684
# Make: Ford
# Model: F-150 Raptor
#
# 34.7% complete
# Trims collected: 1181
# Est. total trims: 3404
# Time elapsed: 0:16:28.929382
# Estimated time remaining: 0:31:02.172685
# Make: Ford
# Model: Mustang Shelby GT500
#
# 34.8% complete
# Trims collected: 1327
# Est. total trims: 3811
# Time elapsed: 0:18:14.057005
# Estimated time remaining: 0:34:08.272137
# Make: Ford
# Model: Transit
#
# 34.9% complete
# Trims collected: 1335
# Est. total trims: 3820
# Time elapsed: 0:18:20.368418
# Estimated time remaining: 0:34:08.251325
# Make: Ford
# Model: Transit Connect
#
# 35.1% complete
# Trims collected: 1335
# Est. total trims: 3805
# Time elapsed: 0:18:21.079017
# Estimated time remaining: 0:33:57.817883
# Make: Ford
# Model: Fusion / Fusion Hybrid
#
# 35.2% complete
# Trims collected: 1337
# Est. total trims: 3797
# Time elapsed: 0:18:22.952140
# Estimated time remaining: 0:33:49.595945
# Make: Ford
# Model: Mustang Shelby GT350
#
# 35.3% complete
# Trims collected: 1341
# Est. total trims: 3794
# Time elapsed: 0:18:26.155730
# Estimated time remaining: 0:33:43.855299
# Make: Ford
# Model: Fiesta
#
# 35.5% complete
# Trims collected: 1342
# Est. total trims: 3783
# Time elapsed: 0:18:27.533405
# Estimated time remaining: 0:33:34.811692
# Make: Ford
# Model: Fiesta ST
#
# 35.6% complete
# Trims collected: 1348
# Est. total trims: 3786
# Time elapsed: 0:18:32.849629
# Estimated time remaining: 0:33:32.948594
# Make: Ford
# Model: Flex
#
# 35.7% complete
# Trims collected: 1354
# Est. total trims: 3789
# Time elapsed: 0:18:37.940287
# Estimated time remaining: 0:33:30.654509
# Make: Ford
# Model: Taurus
#
# 35.9% complete
# Trims collected: 1356
# Est. total trims: 3780
# Time elapsed: 0:18:39.956757
# Estimated time remaining: 0:33:22.842376
# Make: Ford
# Model: C-Max
#
# 36.0% complete
# Trims collected: 1363
# Est. total trims: 3786
# Time elapsed: 0:18:45.825175
# Estimated time remaining: 0:33:21.921857
# Make: Ford
# Model: Focus
#
# 36.1% complete
# Trims collected: 1364
# Est. total trims: 3775
# Time elapsed: 0:18:47.002251
# Estimated time remaining: 0:33:12.670646
# Make: Ford
# Model: Focus Electric
#
# 36.3% complete
# Trims collected: 1365
# Est. total trims: 3764
# Time elapsed: 0:18:48.270786
# Estimated time remaining: 0:33:03.638530
# Make: Ford
# Model: Focus RS
#
# 36.4% complete
# Trims collected: 1366
# Est. total trims: 3754
# Time elapsed: 0:18:48.987926
# Estimated time remaining: 0:32:53.698316
# Make: Ford
# Model: Focus ST
#
# 36.5% complete
# Trims collected: 1366
# Est. total trims: 3740
# Time elapsed: 0:18:50.240161
# Estimated time remaining: 0:32:44.754402
# Make: Ford
# Model: C-Max / C-Max Energi
#
# 36.6% complete
# Trims collected: 1366
# Est. total trims: 3727
# Time elapsed: 0:18:50.896008
# Estimated time remaining: 0:32:34.834529
# Make: Ford
# Model: F-Series Super Duty
#
# 36.8% complete
# Trims collected: 1371
# Est. total trims: 3727
# Time elapsed: 0:18:54.929421
# Estimated time remaining: 0:32:30.786158
# Make: Ford
# Model: Explorer Sport Trac
#
# 36.9% complete
# Trims collected: 1377
# Est. total trims: 3730
# Time elapsed: 0:19:00.828763
# Estimated time remaining: 0:32:29.927176
# Make: Ford
# Model: Taurus X
#
# 37.0% complete
# Trims collected: 1383
# Est. total trims: 3733
# Time elapsed: 0:19:05.688028
# Estimated time remaining: 0:32:27.264810
# Make: Genesis
# Model: G70
#
# 37.2% complete
# Trims collected: 1386
# Est. total trims: 3728
# Time elapsed: 0:19:08.309157
# Estimated time remaining: 0:32:20.804210
# Make: Genesis
# Model: G80
#
# 37.4% complete
# Trims collected: 1388
# Est. total trims: 3707
# Time elapsed: 0:19:10.662046
# Estimated time remaining: 0:32:03.134468
# Make: Genesis
# Model: GV70
#
# 37.6% complete
# Trims collected: 1392
# Est. total trims: 3705
# Time elapsed: 0:19:13.943021
# Estimated time remaining: 0:31:57.877426
# Make: Genesis
# Model: GV80
#
# 37.7% complete
# Trims collected: 1396
# Est. total trims: 3703
# Time elapsed: 0:19:17.491940
# Estimated time remaining: 0:31:53.076956
# Make: Genesis
# Model: G90
#
# 38.2% complete
# Trims collected: 1403
# Est. total trims: 3670
# Time elapsed: 0:19:24.472033
# Estimated time remaining: 0:31:22.297258
# Make: GMC
# Model: Acadia
#
# 38.4% complete
# Trims collected: 1417
# Est. total trims: 3694
# Time elapsed: 0:19:35.952878
# Estimated time remaining: 0:31:30.354285
# Make: GMC
# Model: Canyon
#
# 38.5% complete
# Trims collected: 1417
# Est. total trims: 3682
# Time elapsed: 0:19:36.495167
# Estimated time remaining: 0:31:20.791593
# Make: GMC
# Model: Sierra 1500
#
# 38.6% complete
# Trims collected: 1423
# Est. total trims: 3685
# Time elapsed: 0:19:41.192564
# Estimated time remaining: 0:31:17.895974
# Make: GMC
# Model: Terrain
#
# 38.7% complete
# Trims collected: 1437
# Est. total trims: 3709
# Time elapsed: 0:19:53.037413
# Estimated time remaining: 0:31:26.288882
# Make: GMC
# Model: Yukon
#
# 38.9% complete
# Trims collected: 1452
# Est. total trims: 3735
# Time elapsed: 0:20:08.498718
# Estimated time remaining: 0:31:40.231991
# Make: GMC
# Model: Savana
#
# 39.0% complete
# Trims collected: 1520
# Est. total trims: 3896
# Time elapsed: 0:21:04.425427
# Estimated time remaining: 0:32:57.255870
# Make: GMC
# Model: Sierra HD
#
# 39.1% complete
# Trims collected: 1526
# Est. total trims: 3899
# Time elapsed: 0:21:09.668335
# Estimated time remaining: 0:32:54.567812
# Make: GMC
# Model: Envoy
#
# 39.3% complete
# Trims collected: 1536
# Est. total trims: 3911
# Time elapsed: 0:21:17.548501
# Estimated time remaining: 0:32:55.941682
# Make: Honda
# Model: Civic
#
# 39.5% complete
# Trims collected: 1548
# Est. total trims: 3916
# Time elapsed: 0:21:27.124408
# Estimated time remaining: 0:32:49.044625
# Make: Honda
# Model: CR-V
#
# 39.7% complete
# Trims collected: 1556
# Est. total trims: 3923
# Time elapsed: 0:21:33.586122
# Estimated time remaining: 0:32:48.129381
# Make: Honda
# Model: HR-V
#
# 39.8% complete
# Trims collected: 1556
# Est. total trims: 3910
# Time elapsed: 0:21:33.675743
# Estimated time remaining: 0:32:37.535664
# Make: Honda
# Model: Accord
#
# 39.9% complete
# Trims collected: 1560
# Est. total trims: 3907
# Time elapsed: 0:21:39.977967
# Estimated time remaining: 0:32:36.360285
# Make: Honda
# Model: Civic Si
#
# 40.1% complete
# Trims collected: 1562
# Est. total trims: 3899
# Time elapsed: 0:21:44.307610
# Estimated time remaining: 0:32:32.198972
# Make: Honda
# Model: Civic Type R
#
# 40.2% complete
# Trims collected: 1564
# Est. total trims: 3892
# Time elapsed: 0:21:48.291215
# Estimated time remaining: 0:32:27.521451
# Make: Honda
# Model: Insight
#
# 40.3% complete
# Trims collected: 1569
# Est. total trims: 3891
# Time elapsed: 0:22:00.058884
# Estimated time remaining: 0:32:34.372893
# Make: Honda
# Model: Odyssey
#
# 40.4% complete
# Trims collected: 1569
# Est. total trims: 3879
# Time elapsed: 0:22:02.694789
# Estimated time remaining: 0:32:27.657376
# Make: Honda
# Model: Passport
#
# 40.6% complete
# Trims collected: 1583
# Est. total trims: 3901
# Time elapsed: 0:22:12.843516
# Estimated time remaining: 0:32:31.970826
# Make: Honda
# Model: Pilot
#
# 40.7% complete
# Trims collected: 1586
# Est. total trims: 3896
# Time elapsed: 0:22:15.808619
# Estimated time remaining: 0:32:25.727667
# Make: Honda
# Model: Clarity
#
# 40.8% complete
# Trims collected: 1590
# Est. total trims: 3893
# Time elapsed: 0:22:19.671507
# Estimated time remaining: 0:32:20.806158
# Make: Honda
# Model: Ridgeline
#
# 41.0% complete
# Trims collected: 1596
# Est. total trims: 3895
# Time elapsed: 0:22:24.497592
# Estimated time remaining: 0:32:17.279278
# Make: Honda
# Model: Fit
#
# 41.1% complete
# Trims collected: 1602
# Est. total trims: 3897
# Time elapsed: 0:22:29.867991
# Estimated time remaining: 0:32:14.524191
# Make: Honda
# Model: CR-Z
#
# 41.2% complete
# Trims collected: 1603
# Est. total trims: 3887
# Time elapsed: 0:22:31.180119
# Estimated time remaining: 0:32:05.967852
# Make: Honda
# Model: Fit EV
#
# 41.5% complete
# Trims collected: 1607
# Est. total trims: 3873
# Time elapsed: 0:22:34.755250
# Estimated time remaining: 0:31:50.333113
# Make: Honda
# Model: Element
#
# 41.6% complete
# Trims collected: 1610
# Est. total trims: 3868
# Time elapsed: 0:22:37.415787
# Estimated time remaining: 0:31:43.796984
# Make: Honda
# Model: S2000
#
# 41.9% complete
# Trims collected: 1613
# Est. total trims: 3851
# Time elapsed: 0:22:40.599765
# Estimated time remaining: 0:31:27.832174
# Make: Hyundai
# Model: Accent
#
# 42.0% complete
# Trims collected: 1623
# Est. total trims: 3862
# Time elapsed: 0:22:47.842759
# Estimated time remaining: 0:31:27.708231
# Make: Hyundai
# Model: Elantra
#
# 42.4% complete
# Trims collected: 1639
# Est. total trims: 3864
# Time elapsed: 0:22:59.397440
# Estimated time remaining: 0:31:13.255783
# Make: Hyundai
# Model: Kona
#
# 42.5% complete
# Trims collected: 1641
# Est. total trims: 3857
# Time elapsed: 0:23:01.162701
# Estimated time remaining: 0:31:05.632079
# Make: Hyundai
# Model: Kona Electric
#
# 42.8% complete
# Trims collected: 1641
# Est. total trims: 3834
# Time elapsed: 0:23:01.930364
# Estimated time remaining: 0:30:46.799905
# Make: Hyundai
# Model: Nexo
#
# 42.9% complete
# Trims collected: 1649
# Est. total trims: 3840
# Time elapsed: 0:23:07.073953
# Estimated time remaining: 0:30:43.793425
# Make: Hyundai
# Model: Palisade
#
# 43.1% complete
# Trims collected: 1655
# Est. total trims: 3843
# Time elapsed: 0:23:11.993338
# Estimated time remaining: 0:30:40.477513
# Make: Hyundai
# Model: Santa Cruz
#
# 43.2% complete
# Trims collected: 1670
# Est. total trims: 3866
# Time elapsed: 0:23:22.169267
# Estimated time remaining: 0:30:44.065037
# Make: Hyundai
# Model: Santa Fe
#
# 43.3% complete
# Trims collected: 1676
# Est. total trims: 3868
# Time elapsed: 0:23:27.031165
# Estimated time remaining: 0:30:40.617808
# Make: Hyundai
# Model: Sonata
#
# 43.5% complete
# Trims collected: 1687
# Est. total trims: 3882
# Time elapsed: 0:23:34.536961
# Estimated time remaining: 0:30:40.602311
# Make: Hyundai
# Model: Tucson
#
# 43.6% complete
# Trims collected: 1689
# Est. total trims: 3875
# Time elapsed: 0:23:36.373743
# Estimated time remaining: 0:30:33.204454
# Make: Hyundai
# Model: Veloster N
#
# 43.7% complete
# Trims collected: 1692
# Est. total trims: 3870
# Time elapsed: 0:23:39.314766
# Estimated time remaining: 0:30:27.261525
# Make: Hyundai
# Model: Venue
#
# 43.8% complete
# Trims collected: 1692
# Est. total trims: 3858
# Time elapsed: 0:23:40.263750
# Estimated time remaining: 0:30:18.785518
# Make: Hyundai
# Model: Ioniq
#
# 44.0% complete
# Trims collected: 1694
# Est. total trims: 3851
# Time elapsed: 0:23:42.400226
# Estimated time remaining: 0:30:11.866955
# Make: Hyundai
# Model: Ioniq Electric
#
# 44.1% complete
# Trims collected: 1700
# Est. total trims: 3854
# Time elapsed: 0:23:47.119281
# Estimated time remaining: 0:30:08.249060
# Make: Hyundai
# Model: Veloster
#
# 44.2% complete
# Trims collected: 1703
# Est. total trims: 3849
# Time elapsed: 0:23:49.757760
# Estimated time remaining: 0:30:02.002384
# Make: Hyundai
# Model: Elantra GT
#
# 44.4% complete
# Trims collected: 1705
# Est. total trims: 3842
# Time elapsed: 0:23:51.731820
# Estimated time remaining: 0:29:54.944023
# Make: Hyundai
# Model: Elantra Sport
#
# 44.5% complete
# Trims collected: 1711
# Est. total trims: 3844
# Time elapsed: 0:23:56.351077
# Estimated time remaining: 0:29:51.214284
# Make: Hyundai
# Model: Santa Fe Sport
#
# 44.6% complete
# Trims collected: 1713
# Est. total trims: 3837
# Time elapsed: 0:23:58.388319
# Estimated time remaining: 0:29:44.276420
# Make: Hyundai
# Model: Azera
#
# 44.8% complete
# Trims collected: 1715
# Est. total trims: 3831
# Time elapsed: 0:24:00.607996
# Estimated time remaining: 0:29:37.592323
# Make: Hyundai
# Model: Equus
#
# 44.9% complete
# Trims collected: 1718
# Est. total trims: 3826
# Time elapsed: 0:24:02.992351
# Estimated time remaining: 0:29:31.136384
# Make: Hyundai
# Model: Genesis
#
# 45.0% complete
# Trims collected: 1727
# Est. total trims: 3835
# Time elapsed: 0:24:10.115872
# Estimated time remaining: 0:29:30.490309
# Make: Hyundai
# Model: Genesis coupe
#
# 45.3% complete
# Trims collected: 1731
# Est. total trims: 3822
# Time elapsed: 0:24:13.816958
# Estimated time remaining: 0:29:16.345342
# Make: Hyundai
# Model: Elantra Touring
#
# 45.4% complete
# Trims collected: 1735
# Est. total trims: 3820
# Time elapsed: 0:24:17.440066
# Estimated time remaining: 0:29:11.448148
# Make: Hyundai
# Model: Veracruz
#
# 45.5% complete
# Trims collected: 1735
# Est. total trims: 3809
# Time elapsed: 0:24:18.291701
# Estimated time remaining: 0:29:03.245252
# Make: Hyundai
# Model: Entourage
#
# 45.7% complete
# Trims collected: 1741
# Est. total trims: 3811
# Time elapsed: 0:24:23.528014
# Estimated time remaining: 0:29:00.298354
# Make: Hyundai
# Model: Tiburon
#
# 45.9% complete
# Trims collected: 1741
# Est. total trims: 3789
# Time elapsed: 0:24:24.410072
# Estimated time remaining: 0:28:43.080797
# Make: Infiniti
# Model: Q50
#
# 46.1% complete
# Trims collected: 1741
# Est. total trims: 3778
# Time elapsed: 0:24:25.145504
# Estimated time remaining: 0:28:34.886215
# Make: Infiniti
# Model: Q60
#
# 46.2% complete
# Trims collected: 1741
# Est. total trims: 3768
# Time elapsed: 0:24:25.610408
# Estimated time remaining: 0:28:26.418917
# Make: Infiniti
# Model: QX50
#
# 46.3% complete
# Trims collected: 1741
# Est. total trims: 3757
# Time elapsed: 0:24:25.718400
# Estimated time remaining: 0:28:17.583457
# Make: Infiniti
# Model: QX60
#
# 46.5% complete
# Trims collected: 1741
# Est. total trims: 3746
# Time elapsed: 0:24:25.817903
# Estimated time remaining: 0:28:08.787387
# Make: Infiniti
# Model: QX80
#
# 46.6% complete
# Trims collected: 1741
# Est. total trims: 3736
# Time elapsed: 0:24:26.497068
# Estimated time remaining: 0:28:00.704505
# Make: Infiniti
# Model: Q50 Red Sport 400
#
# 46.7% complete
# Trims collected: 1741
# Est. total trims: 3725
# Time elapsed: 0:24:27.072084
# Estimated time remaining: 0:27:52.544365
# Make: Infiniti
# Model: Q60 Red Sport 400
#
# 46.9% complete
# Trims collected: 1749
# Est. total trims: 3732
# Time elapsed: 0:24:34.029426
# Estimated time remaining: 0:27:51.664656
# Make: Infiniti
# Model: Q70
#
# 47.0% complete
# Trims collected: 1761
# Est. total trims: 3747
# Time elapsed: 0:24:42.244313
# Estimated time remaining: 0:27:52.169769
# Make: Infiniti
# Model: QX30
#
# 47.1% complete
# Trims collected: 1763
# Est. total trims: 3741
# Time elapsed: 0:24:44.571579
# Estimated time remaining: 0:27:46.019217
# Make: Infiniti
# Model: QX70
#
# 47.3% complete
# Trims collected: 1767
# Est. total trims: 3739
# Time elapsed: 0:24:48.047349
# Estimated time remaining: 0:27:41.171972
# Make: Infiniti
# Model: EX37
#
# 47.4% complete
# Trims collected: 1778
# Est. total trims: 3752
# Time elapsed: 0:24:56.640284
# Estimated time remaining: 0:27:42.014901
# Make: Infiniti
# Model: G25 / G37
#
# 47.5% complete
# Trims collected: 1780
# Est. total trims: 3746
# Time elapsed: 0:24:58.542980
# Estimated time remaining: 0:27:35.415248
# Make: Infiniti
# Model: JX35
#
# 47.6% complete
# Trims collected: 1785
# Est. total trims: 3746
# Time elapsed: 0:25:02.373136
# Estimated time remaining: 0:27:30.959490
# Make: Infiniti
# Model: M35 / M37 / M56
#
# 47.8% complete
# Trims collected: 1789
# Est. total trims: 3744
# Time elapsed: 0:25:06.476082
# Estimated time remaining: 0:27:26.805360
# Make: Infiniti
# Model: QX56
#
# 47.9% complete
# Trims collected: 1789
# Est. total trims: 3734
# Time elapsed: 0:25:06.952969
# Estimated time remaining: 0:27:18.708420
# Make: Jaguar
# Model: F-type
#
# 48.0% complete
# Trims collected: 1792
# Est. total trims: 3730
# Time elapsed: 0:25:09.429147
# Estimated time remaining: 0:27:12.815726
# Make: Jaguar
# Model: E-Pace
#
# 48.2% complete
# Trims collected: 1792
# Est. total trims: 3720
# Time elapsed: 0:25:09.934913
# Estimated time remaining: 0:27:04.821265
# Make: Jaguar
# Model: F-Pace
#
# 48.3% complete
# Trims collected: 1792
# Est. total trims: 3710
# Time elapsed: 0:25:10.593190
# Estimated time remaining: 0:26:57.030650
# Make: Jaguar
# Model: F-Pace SVR
#
# 48.4% complete
# Trims collected: 1793
# Est. total trims: 3702
# Time elapsed: 0:25:12.042804
# Estimated time remaining: 0:26:50.121256
# Make: Jaguar
# Model: I-Pace
#
# 48.6% complete
# Trims collected: 1796
# Est. total trims: 3698
# Time elapsed: 0:25:14.758166
# Estimated time remaining: 0:26:44.582100
# Make: Jaguar
# Model: XF
#
# 48.8% complete
# Trims collected: 1796
# Est. total trims: 3678
# Time elapsed: 0:25:15.480712
# Estimated time remaining: 0:26:28.613830
# Make: Jaguar
# Model: F-type R / SVR
#
# 49.0% complete
# Trims collected: 1799
# Est. total trims: 3674
# Time elapsed: 0:25:18.623977
# Estimated time remaining: 0:26:23.591848
# Make: Jaguar
# Model: XE
#
# 49.1% complete
# Trims collected: 1801
# Est. total trims: 3669
# Time elapsed: 0:25:20.583578
# Estimated time remaining: 0:26:17.352031
# Make: Jaguar
# Model: XF Sportbrake
#
# 49.2% complete
# Trims collected: 1810
# Est. total trims: 3677
# Time elapsed: 0:25:27.431310
# Estimated time remaining: 0:26:16.179118
# Make: Jaguar
# Model: XJ
#
# 49.3% complete
# Trims collected: 1811
# Est. total trims: 3670
# Time elapsed: 0:25:29.027733
# Estimated time remaining: 0:26:09.585498
# Make: Jaguar
# Model: XJR575
#
# 49.5% complete
# Trims collected: 1813
# Est. total trims: 3664
# Time elapsed: 0:25:30.921608
# Estimated time remaining: 0:26:03.322066
# Make: Jaguar
# Model: XK
#
# 49.6% complete
# Trims collected: 1817
# Est. total trims: 3662
# Time elapsed: 0:25:34.976566
# Estimated time remaining: 0:25:59.276987
# Make: Jaguar
# Model: XKR / XKR-S
#
# 49.7% complete
# Trims collected: 1836
# Est. total trims: 3691
# Time elapsed: 0:25:47.679939
# ...
#
# 86.0% complete
# Trims collected: 2781
# Est. total trims: 3233
# Time elapsed: 0:39:24.847588
# Estimated time remaining: 0:06:25.142606
# Make: Porsche
# Model: 911 GT2 RS
#
# 86.1% complete
# Trims collected: 2783
# Est. total trims: 3231
# Time elapsed: 0:39:26.856575
# Estimated time remaining: 0:06:21.286926
# Make: Porsche
# Model: 918
#
# 86.4% complete
# Trims collected: 2825
# Est. total trims: 3270
# Time elapsed: 0:39:56.856675
# Estimated time remaining: 0:06:17.686506
# Make: Ram
# Model: 1500
#
# 86.5% complete
# Trims collected: 2826
# Est. total trims: 3266
# Time elapsed: 0:39:58.316698
# Estimated time remaining: 0:06:13.716520
# Make: Ram
# Model: TRX
#
# 86.6% complete
# Trims collected: 2826
# Est. total trims: 3261
# Time elapsed: 0:39:59.015394
# Estimated time remaining: 0:06:09.636813
# Make: Ram
# Model: ProMaster
#
# 86.8% complete
# Trims collected: 2826
# Est. total trims: 3256
# Time elapsed: 0:39:59.529183
# Estimated time remaining: 0:06:05.539137
# Make: Ram
# Model: Dakota
#
# 86.9% complete
# Trims collected: 2925
# Est. total trims: 3365
# Time elapsed: 0:41:28.791564
# Estimated time remaining: 0:06:14.818007
# Make: Ram
# Model: Ram HD
#
# 87.0% complete
# Trims collected: 2929
# Est. total trims: 3365
# Time elapsed: 0:41:32.121435
# Estimated time remaining: 0:06:11.007552
# Make: Ram
# Model: ProMaster City
#
# 87.2% complete
# Trims collected: 2929
# Est. total trims: 3359
# Time elapsed: 0:41:32.577440
# Estimated time remaining: 0:06:06.775659
# Make: Ram
# Model: 2500/3500
#
# 87.7% complete
# Trims collected: 2930
# Est. total trims: 3341
# Time elapsed: 0:41:34.645098
# Estimated time remaining: 0:05:49.994984
# Make: Rolls-Royce
# Model: Ghost
#
# 87.8% complete
# Trims collected: 2932
# Est. total trims: 3338
# Time elapsed: 0:41:36.918758
# Estimated time remaining: 0:05:46.070707
# Make: Rolls-Royce
# Model: Phantom
#
# 88.0% complete
# Trims collected: 2933
# Est. total trims: 3334
# Time elapsed: 0:41:38.054937
# Estimated time remaining: 0:05:41.995616
# Make: Rolls-Royce
# Model: Cullinan
#
# 88.1% complete
# Trims collected: 2934
# Est. total trims: 3330
# Time elapsed: 0:41:39.296898
# Estimated time remaining: 0:05:37.943563
# Make: Rolls-Royce
# Model: Dawn
#
# 88.2% complete
# Trims collected: 2934
# Est. total trims: 3325
# Time elapsed: 0:41:39.815950
# Estimated time remaining: 0:05:33.803317
# Make: Rolls-Royce
# Model: Wraith
#
# 88.4% complete
# Trims collected: 2938
# Est. total trims: 3325
# Time elapsed: 0:41:43.356881
# Estimated time remaining: 0:05:30.072241
# Make: Subaru
# Model: BRZ
#
# 88.6% complete
# Trims collected: 2945
# Est. total trims: 3323
# Time elapsed: 0:41:50.177012
# Estimated time remaining: 0:05:22.578139
# Make: Subaru
# Model: Ascent
#
# 88.7% complete
# Trims collected: 2951
# Est. total trims: 3325
# Time elapsed: 0:41:54.483853
# Estimated time remaining: 0:05:18.946329
# Make: Subaru
# Model: Forester
#
# 88.9% complete
# Trims collected: 2961
# Est. total trims: 3331
# Time elapsed: 0:42:02.722929
# Estimated time remaining: 0:05:15.804785
# Make: Subaru
# Model: Impreza
#
# 89.0% complete
# Trims collected: 2967
# Est. total trims: 3333
# Time elapsed: 0:42:08.420829
# Estimated time remaining: 0:05:12.334338
# Make: Subaru
# Model: Legacy
#
# 89.1% complete
# Trims collected: 2975
# Est. total trims: 3337
# Time elapsed: 0:42:14.780704
# Estimated time remaining: 0:05:08.938030
# Make: Subaru
# Model: Outback
#
# 89.3% complete
# Trims collected: 2980
# Est. total trims: 3338
# Time elapsed: 0:42:18.881516
# Estimated time remaining: 0:05:05.261414
# Make: Subaru
# Model: WRX
#
# 89.4% complete
# Trims collected: 2987
# Est. total trims: 3341
# Time elapsed: 0:42:24.531241
# Estimated time remaining: 0:05:01.767248
# Make: Subaru
# Model: Crosstrek
#
# 89.5% complete
# Trims collected: 2990
# Est. total trims: 3339
# Time elapsed: 0:42:27.373794
# Estimated time remaining: 0:04:57.938455
# Make: Subaru
# Model: WRX STI
#
# 89.7% complete
# Trims collected: 2991
# Est. total trims: 3335
# Time elapsed: 0:42:28.896091
# Estimated time remaining: 0:04:53.960279
# Make: Subaru
# Model: Tribeca
#
# 89.9% complete
# Trims collected: 2995
# Est. total trims: 3330
# Time elapsed: 0:42:32.287158
# Estimated time remaining: 0:04:46.064208
# Make: Tesla
# Model: Model S
#
# 90.1% complete
# Trims collected: 2995
# Est. total trims: 3325
# Time elapsed: 0:42:32.704981
# Estimated time remaining: 0:04:41.984853
# Make: Tesla
# Model: Model 3
#
# 90.2% complete
# Trims collected: 2995
# Est. total trims: 3321
# Time elapsed: 0:42:32.794618
# Estimated time remaining: 0:04:37.880401
# Make: Tesla
# Model: Model X
#
# 90.3% complete
# Trims collected: 2995
# Est. total trims: 3316
# Time elapsed: 0:42:33.432334
# Estimated time remaining: 0:04:33.846366
# Make: Tesla
# Model: Model Y
#
# 90.4% complete
# Trims collected: 2995
# Est. total trims: 3311
# Time elapsed: 0:42:34.154578
# Estimated time remaining: 0:04:29.831091
# Make: Tesla
# Model: Roadster
#
# 90.6% complete
# Trims collected: 2995
# Est. total trims: 3306
# Time elapsed: 0:42:34.564617
# Estimated time remaining: 0:04:25.792850
# Make: Toyota
# Model: GR 86
#
# 90.7% complete
# Trims collected: 3014
# Est. total trims: 3322
# Time elapsed: 0:42:48.654615
# Estimated time remaining: 0:04:23.166634
# Make: Toyota
# Model: Tacoma
#
# 90.8% complete
# Trims collected: 3028
# Est. total trims: 3333
# Time elapsed: 0:42:58.686487
# Estimated time remaining: 0:04:20.098061
# Make: Toyota
# Model: 4Runner
#
# 91.0% complete
# Trims collected: 3034
# Est. total trims: 3335
# Time elapsed: 0:43:03.076002
# Estimated time remaining: 0:04:16.449272
# Make: Toyota
# Model: Avalon
#
# 91.5% complete
# Trims collected: 3034
# Est. total trims: 3316
# Time elapsed: 0:43:03.828955
# Estimated time remaining: 0:04:00.270218
# Make: Toyota
# Model: Highlander
#
# 91.6% complete
# Trims collected: 3040
# Est. total trims: 3317
# Time elapsed: 0:43:09.362745
# Estimated time remaining: 0:03:56.741737
# Make: Toyota
# Model: Prius
#
# 91.8% complete
# Trims collected: 3040
# Est. total trims: 3313
# Time elapsed: 0:43:09.460354
# Estimated time remaining: 0:03:52.718976
# Make: Toyota
# Model: Sienna
#
# 91.9% complete
# Trims collected: 3051
# Est. total trims: 3320
# Time elapsed: 0:43:17.408761
# Estimated time remaining: 0:03:49.400774
# Make: Toyota
# Model: Sequoia
#
# 92.0% complete
# Trims collected: 3055
# Est. total trims: 3320
# Time elapsed: 0:43:19.563855
# Estimated time remaining: 0:03:45.566707
# Make: Toyota
# Model: Supra
#
# 92.1% complete
# Trims collected: 3055
# Est. total trims: 3315
# Time elapsed: 0:43:19.655070
# Estimated time remaining: 0:03:41.561512
# Make: Toyota
# Model: Tundra
#
# 92.3% complete
# Trims collected: 3072
# Est. total trims: 3329
# Time elapsed: 0:43:31.682835
# Estimated time remaining: 0:03:38.566365
# Make: Toyota
# Model: Camry
#
# 92.4% complete
# Trims collected: 3076
# Est. total trims: 3328
# Time elapsed: 0:43:35.441726
# Estimated time remaining: 0:03:34.866317
# Make: Toyota
# Model: C-HR
#
# 92.5% complete
# Trims collected: 3092
# Est. total trims: 3341
# Time elapsed: 0:43:47.102267
# Estimated time remaining: 0:03:31.803153
# Make: Toyota
# Model: Corolla
#
# 92.7% complete
# Trims collected: 3094
# Est. total trims: 3338
# Time elapsed: 0:43:49.672061
# Estimated time remaining: 0:03:27.996660
# Make: Toyota
# Model: Land Cruiser
#
# 92.8% complete
# Trims collected: 3096
# Est. total trims: 3336
# Time elapsed: 0:43:51.518481
# Estimated time remaining: 0:03:24.137541
# Make: Toyota
# Model: Mirai
#
# 92.9% complete
# Trims collected: 3099
# Est. total trims: 3334
# Time elapsed: 0:43:53.799381
# Estimated time remaining: 0:03:20.317136
# Make: Toyota
# Model: Prius Prime
#
# 93.1% complete
# Trims collected: 3109
# Est. total trims: 3340
# Time elapsed: 0:44:01.315146
# Estimated time remaining: 0:03:16.891284
# Make: Toyota
# Model: RAV4
#
# 93.2% complete
# Trims collected: 3118
# Est. total trims: 3345
# Time elapsed: 0:44:08.246729
# Estimated time remaining: 0:03:13.411278
# Make: Toyota
# Model: RAV4 Hybrid
#
# 93.3% complete
# Trims collected: 3121
# Est. total trims: 3344
# Time elapsed: 0:44:10.752097
# Estimated time remaining: 0:03:09.604989
# Make: Toyota
# Model: Venza
#
# 93.5% complete
# Trims collected: 3121
# Est. total trims: 3339
# Time elapsed: 0:44:11.386969
# Estimated time remaining: 0:03:05.671356
# Make: Toyota
# Model: 86
#
# 93.6% complete
# Trims collected: 3128
# Est. total trims: 3342
# Time elapsed: 0:44:16.865904
# Estimated time remaining: 0:03:02.078922
# Make: Toyota
# Model: Yaris
#
# 93.7% complete
# Trims collected: 3130
# Est. total trims: 3339
# Time elapsed: 0:44:18.895331
# Estimated time remaining: 0:02:58.249966
# Make: Toyota
# Model: Prius C
#
# 93.8% complete
# Trims collected: 3134
# Est. total trims: 3339
# Time elapsed: 0:44:22.453464
# Estimated time remaining: 0:02:54.526238
# Make: Toyota
# Model: Prius V
#
# 94.0% complete
# Trims collected: 3135
# Est. total trims: 3335
# Time elapsed: 0:44:23.704787
# Estimated time remaining: 0:02:50.655181
# Make: Toyota
# Model: Corolla iM
#
# 94.1% complete
# Trims collected: 3137
# Est. total trims: 3333
# Time elapsed: 0:44:25.885366
# Estimated time remaining: 0:02:46.849571
# Make: Toyota
# Model: Yaris iA
#
# 94.2% complete
# Trims collected: 3142
# Est. total trims: 3334
# Time elapsed: 0:44:29.704494
# Estimated time remaining: 0:02:43.148608
# Make: Toyota
# Model: Matrix
#
# 94.4% complete
# Trims collected: 3153
# Est. total trims: 3341
# Time elapsed: 0:44:38.075918
# Estimated time remaining: 0:02:39.718813
# Make: Toyota
# Model: Camry Solara
#
# 94.8% complete
# Trims collected: 3153
# Est. total trims: 3327
# Time elapsed: 0:44:39.147101
# Estimated time remaining: 0:02:28.019177
# Make: Volkswagen
# Model: Arteon
#
# 94.9% complete
# Trims collected: 3166
# Est. total trims: 3336
# Time elapsed: 0:44:49.711434
# Estimated time remaining: 0:02:24.687925
# Make: Volkswagen
# Model: Atlas Cross Sport
#
# 95.0% complete
# Trims collected: 3172
# Est. total trims: 3338
# Time elapsed: 0:44:53.570876
# Estimated time remaining: 0:02:20.985803
# Make: Volkswagen
# Model: Golf GTI
#
# 95.2% complete
# Trims collected: 3174
# Est. total trims: 3335
# Time elapsed: 0:44:55.331254
# Estimated time remaining: 0:02:17.176419
# Make: Volkswagen
# Model: Golf R
#
# 95.3% complete
# Trims collected: 3174
# Est. total trims: 3330
# Time elapsed: 0:44:55.424407
# Estimated time remaining: 0:02:13.290218
# Make: Volkswagen
# Model: Jetta
#
# 95.4% complete
# Trims collected: 3174
# Est. total trims: 3326
# Time elapsed: 0:44:55.931866
# Estimated time remaining: 0:02:09.434315
# Make: Volkswagen
# Model: Jetta GLI
#
# 95.5% complete
# Trims collected: 3177
# Est. total trims: 3324
# Time elapsed: 0:44:58.412994
# Estimated time remaining: 0:02:05.679509
# Make: Volkswagen
# Model: Passat
#
# 95.7% complete
# Trims collected: 3183
# Est. total trims: 3326
# Time elapsed: 0:45:02.936921
# Estimated time remaining: 0:02:02.020408
# Make: Volkswagen
# Model: Taos
#
# 95.8% complete
# Trims collected: 3190
# Est. total trims: 3329
# Time elapsed: 0:45:07.459828
# Estimated time remaining: 0:01:58.358900
# Make: Volkswagen
# Model: Tiguan
#
# 95.9% complete
# Trims collected: 3226
# Est. total trims: 3362
# Time elapsed: 0:45:31.900179
# Estimated time remaining: 0:01:55.537388
# Make: Volkswagen
# Model: Atlas
#
# 96.1% complete
# Trims collected: 3228
# Est. total trims: 3359
# Time elapsed: 0:45:33.855284
# Estimated time remaining: 0:01:51.737954
# Make: Volkswagen
# Model: Golf
#
# 96.2% complete
# Trims collected: 3233
# Est. total trims: 3360
# Time elapsed: 0:45:36.978254
# Estimated time remaining: 0:01:47.989618
# Make: Volkswagen
# Model: ID.4
#
# 96.3% complete
# Trims collected: 3241
# Est. total trims: 3364
# Time elapsed: 0:45:43.632082
# Estimated time remaining: 0:01:44.377307
# Make: Volkswagen
# Model: Beetle
#
# 96.5% complete
# Trims collected: 3243
# Est. total trims: 3361
# Time elapsed: 0:45:45.376116
# Estimated time remaining: 0:01:40.576873
# Make: Volkswagen
# Model: e-Golf
#
# 96.6% complete
# Trims collected: 3249
# Est. total trims: 3363
# Time elapsed: 0:45:50.774973
# Estimated time remaining: 0:01:36.910771
# Make: Volkswagen
# Model: Golf Alltrack
#
# 96.7% complete
# Trims collected: 3254
# Est. total trims: 3364
# Time elapsed: 0:45:54.607980
# Estimated time remaining: 0:01:33.187009
# Make: Volkswagen
# Model: Golf SportWagen
#
# 96.9% complete
# Trims collected: 3257
# Est. total trims: 3362
# Time elapsed: 0:45:57.143845
# Estimated time remaining: 0:01:29.420881
# Make: Volkswagen
# Model: CC
#
# 97.0% complete
# Trims collected: 3260
# Est. total trims: 3361
# Time elapsed: 0:45:59.607802
# Estimated time remaining: 0:01:25.655843
# Make: Volkswagen
# Model: Touareg
#
# 97.1% complete
# Trims collected: 3261
# Est. total trims: 3357
# Time elapsed: 0:46:01.029748
# Estimated time remaining: 0:01:21.863416
# Make: Volkswagen
# Model: Eos
#
# 97.3% complete
# Trims collected: 3268
# Est. total trims: 3360
# Time elapsed: 0:46:07.519247
# Estimated time remaining: 0:01:18.220598
# Make: Volkswagen
# Model: Routan
#
# 97.4% complete
# Trims collected: 3274
# Est. total trims: 3362
# Time elapsed: 0:46:12.691321
# Estimated time remaining: 0:01:14.534713
# Make: Volkswagen
# Model: New Beetle
#
# 97.5% complete
# Trims collected: 3277
# Est. total trims: 3360
# Time elapsed: 0:46:15.089163
# Estimated time remaining: 0:01:10.774086
# Make: Volkswagen
# Model: Rabbit
#
# 97.6% complete
# Trims collected: 3278
# Est. total trims: 3357
# Time elapsed: 0:46:15.774362
# Estimated time remaining: 0:01:06.975789
# Make: Volvo
# Model: C40 Recharge
#
# 97.8% complete
# Trims collected: 3288
# Est. total trims: 3362
# Time elapsed: 0:46:23.692932
# Estimated time remaining: 0:01:03.350442
# Make: Volvo
# Model: S60
#
# 97.9% complete
# Trims collected: 3293
# Est. total trims: 3363
# Time elapsed: 0:46:27.719713
# Estimated time remaining: 0:00:59.630368
# Make: Volvo
# Model: S90
#
# 98.0% complete
# Trims collected: 3295
# Est. total trims: 3360
# Time elapsed: 0:46:29.519435
# Estimated time remaining: 0:00:55.864875
# Make: Volvo
# Model: V60 / V60 Cross Country
#
# 98.2% complete
# Trims collected: 3301
# Est. total trims: 3362
# Time elapsed: 0:46:34.081886
# Estimated time remaining: 0:00:52.156195
# Make: Volvo
# Model: XC40
#
# 98.3% complete
# Trims collected: 3303
# Est. total trims: 3360
# Time elapsed: 0:46:35.811022
# Estimated time remaining: 0:00:48.396196
# Make: Volvo
# Model: XC40 Recharge
#
# 98.4% complete
# Trims collected: 3303
# Est. total trims: 3355
# Time elapsed: 0:46:35.899425
# Estimated time remaining: 0:00:44.615416
# Make: Volvo
# Model: XC60
#
# 98.6% complete
# Trims collected: 3314
# Est. total trims: 3362
# Time elapsed: 0:46:44.157335
# Estimated time remaining: 0:00:40.963786
# Make: Volvo
# Model: XC90
#
# 98.7% complete
# Trims collected: 3315
# Est. total trims: 3358
# Time elapsed: 0:46:45.426334
# Estimated time remaining: 0:00:37.207246
# Make: Volvo
# Model: V90 Cross Country
#
# 98.8% complete
# Trims collected: 3319
# Est. total trims: 3358
# Time elapsed: 0:46:48.796491
# Estimated time remaining: 0:00:33.482342
# Make: Volvo
# Model: V90
#
# 99.0% complete
# Trims collected: 3319
# Est. total trims: 3354
# Time elapsed: 0:46:49.296263
# Estimated time remaining: 0:00:29.728003
# Make: Volvo
# Model: V90 / V90 Cross Country
#
# 99.1% complete
# Trims collected: 3321
# Est. total trims: 3351
# Time elapsed: 0:46:51.264244
# Estimated time remaining: 0:00:25.995838
# Make: Volvo
# Model: S80
#
# 99.2% complete
# Trims collected: 3327
# Est. total trims: 3353
# Time elapsed: 0:46:55.784688
# Estimated time remaining: 0:00:22.288533
# Make: Volvo
# Model: XC70
#
# 99.3% complete
# Trims collected: 3343
# Est. total trims: 3365
# Time elapsed: 0:47:07.996644
# Estimated time remaining: 0:00:18.629754
# Make: Volvo
# Model: C30
#
# 99.5% complete
# Trims collected: 3349
# Est. total trims: 3366
# Time elapsed: 0:47:13.008061
# Estimated time remaining: 0:00:14.910569
# Make: Volvo
# Model: C70
#
# 99.6% complete
# Trims collected: 3352
# Est. total trims: 3365
# Time elapsed: 0:47:15.844099
# Estimated time remaining: 0:00:11.179412
# Make: Volvo
# Model: S40
#
# 99.7% complete
# Trims collected: 3355
# Est. total trims: 3363
# Time elapsed: 0:47:18.748169
# Estimated time remaining: 0:00:07.450783
# Make: Volvo
# Model: V50
#
# 99.9% complete
# Trims collected: 3358
# Est. total trims: 3362
# Time elapsed: 0:47:21.362957
# Estimated time remaining: 0:00:03.723936
# Make: Volvo
# Model: V70

# %% [markdown]
# ## Create a DataFrame from the `vehicle_specs` dictionary

# %%
min_len = 9999999999
for k, v in vehicle_specs.items():
    print(k, '\nCount:', len(v))
    min_len = min(min_len, len(v))
    print(v[:10], '\n')
# Out:
# Trim_ID
# Count: 3358
# [419574, 419576, 419573, 419575, 419577, 419578, 423562, 423561, 423560, 423559]
#
# Make
# Count: 3358
# ['Acura', 'Acura', 'Acura', 'Acura', 'Acura', 'Acura', 'Acura', 'Acura', 'Acura', 'Acura']
#
# Model
# Count: 3358
# ['MDX', 'MDX', 'MDX', 'MDX', 'MDX', 'MDX', 'ILX', 'ILX', 'ILX', 'ILX']
#
# Year
# Count: 3358
# [2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022]
#
# Style
# Count: 3358
# ['Acura MDX', 'Acura MDX', 'Acura MDX', 'Acura MDX', 'Acura MDX', 'Acura MDX', 'Acura ILX', 'Acura ILX', 'Acura ILX', 'Acura ILX']
#
# Trim
# Count: 3358
# ['MDX SH-AWD w/Technology Package', 'MDX SH-AWD w/Advance Package', 'MDX SH-AWD', 'MDX SH-AWD w/A-Spec Package', 'MDX FWD', 'MDX FWD w/Technology Package', 'ILX Sedan w/Technology/A-Spec Package', 'ILX Sedan w/Premium/A-Spec Package', 'ILX Sedan w/Premium Package', 'ILX Sedan']
#
# Body_style
# Count: 3358
# ['suv', 'suv', 'suv', 'suv', 'suv', 'suv', 'sedan', 'sedan', 'sedan', 'sedan']
#
# EPA_class
# Count: 3358
# ['Small SUV 4WD', 'Small SUV 4WD', 'Small SUV 4WD', 'Small SUV 4WD', 'Small SUV 2WD', 'Small SUV 2WD', 'Compact Cars', 'Compact Cars', 'Compact Cars', 'Compact Cars']
#
# Pct_domestic_content
# Count: 3358
# [0.64, 0.64, 0.64, 0.64, 0.64, 0.64, 0.55, 0.55, 0.55, 0.55]
#
# Origin
# Count: 3358
# ['domestic', 'domestic', 'domestic', 'domestic', 'domestic', 'domestic', 'domestic', 'domestic', 'domestic', 'domestic']
#
# URL
# Count: 3358
# ['https://www.caranddriver.com/acura/mdx/specs/2022/acura_mdx_acura-mdx_2022/419574', 'https://www.caranddriver.com/acura/mdx/specs/2022/acura_mdx_acura-mdx_2022/419576', 'https://www.caranddriver.com/acura/mdx/specs/2022/acura_mdx_acura-mdx_2022/419573', 'https://www.caranddriver.com/acura/mdx/specs/2022/acura_mdx_acura-mdx_2022/419575', 'https://www.caranddriver.com/acura/mdx/specs/2022/acura_mdx_acura-mdx_2022/419577', 'https://www.caranddriver.com/acura/mdx/specs/2022/acura_mdx_acura-mdx_2022/419578', 'https://www.caranddriver.com/acura/ilx/specs/2022/acura_ilx_acura-ilx_2022/423562', 'https://www.caranddriver.com/acura/ilx/specs/2022/acura_ilx_acura-ilx_2022/423561', 'https://www.caranddriver.com/acura/ilx/specs/2022/acura_ilx_acura-ilx_2022/423560', 'https://www.caranddriver.com/acura/ilx/specs/2022/acura_ilx_acura-ilx_2022/423559']
#
# Image
# Count: 3358
# ['https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/acura_mdx_acura-mdx_2022-1636133370049.jpg', 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/acura_mdx_acura-mdx_2022-1636133370049.jpg', 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/acura_mdx_acura-mdx_2022-1636133370049.jpg', 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/acura_mdx_acura-mdx_2022-1636133370049.jpg', 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/acura_mdx_acura-mdx_2022-1636133370049.jpg', 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/acura_mdx_acura-mdx_2022-1636133370049.jpg', 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/acura_ilx_acura-ilx_2022-1636143076846.jpg', 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/acura_ilx_acura-ilx_2022-1636143076846.jpg', 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/acura_ilx_acura-ilx_2022-1636143076846.jpg', 'https://hips.hearstapps.com/amv-prod-cad-assets.s3.amazonaws.com/vdat/submodels/acura_ilx_acura-ilx_2022-1636143076846.jpg']
#
# Price
# Count: 3358
# [54945.0, 61995.0, 50245.0, 58445.0, 48245.0, 52945.0, 33445.0, 31545.0, 29545.0, 27545.0]
#
# Drivetrain
# Count: 3358
# ['All Wheel Drive', 'All Wheel Drive', 'All Wheel Drive', 'All Wheel Drive', 'Front Wheel Drive', 'Front Wheel Drive', 'Front Wheel Drive', 'Front Wheel Drive', 'Front Wheel Drive', 'Front Wheel Drive']
#
# Engine
# Count: 3358
# ['Premium Unleaded V-6', 'Premium Unleaded V-6', 'Premium Unleaded V-6', 'Premium Unleaded V-6', 'Premium Unleaded V-6', 'Premium Unleaded V-6', 'Premium Unleaded I-4', 'Premium Unleaded I-4', 'Premium Unleaded I-4', 'Premium Unleaded I-4']
#
# Engine_size_liters
# Count: 3358
# [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 2.4, 2.4, 2.4, 2.4]
#
# Engine_size_inches
# Count: 3358
# [212.0, 212.0, 212.0, 212.0, 212.0, 212.0, 144.0, 144.0, 144.0, 144.0]
#
# Max_horsepower
# Count: 3358
# [290.0, 290.0, 290.0, 290.0, 290.0, 290.0, 201.0, 201.0, 201.0, 201.0]
#
# RPM_max_hp
# Count: 3358
# [6200.0, 6200.0, 6200.0, 6200.0, 6200.0, 6200.0, 6800.0, 6800.0, 6800.0, 6800.0]
#
# Max_torque
# Count: 3358
# [267.0, 267.0, 267.0, 267.0, 267.0, 267.0, 180.0, 180.0, 180.0, 180.0]
#
# RPM_max_torque
# Count: 3358
# [4700.0, 4700.0, 4700.0, 4700.0, 4700.0, 4700.0, 3600.0, 3600.0, 3600.0, 3600.0]
#
# Transmission_type
# Count: 3358
# ['Automatic w/OD', 'Automatic w/OD', 'Automatic w/OD', 'Automatic w/OD', 'Automatic w/OD', 'Automatic w/OD', 'Auto-Shift Manual w/OD', 'Auto-Shift Manual w/OD', 'Auto-Shift Manual w/OD', 'Auto-Shift Manual w/OD']
#
# Transmission_gears
# Count: 3358
# ['10', '10', '10', '10', '10', '10', '8', '8', '8', '8']
#
# CO2_emmissions
# Count: 3358
# [8.4, 8.4, 8.4, 8.4, 8.0, 8.0, 6.3, 6.3, 6.3, 6.3]
#
# MPG_city
# Count: 3358
# [19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 24.0, 24.0, 24.0, 24.0]
#
# MPG_highway
# Count: 3358
# [25.0, 25.0, 25.0, 25.0, 26.0, 26.0, 34.0, 34.0, 34.0, 34.0]
#
# MPG_combined
# Count: 3358
# [21.0, 21.0, 21.0, 21.0, 22.0, 22.0, 28.0, 28.0, 28.0, 28.0]
#
# Fuel_capacity_gallons
# Count: 3358
# [18.5, 18.5, 18.5, 18.5, 18.5, 18.5, 13.2, 13.2, 13.2, 13.2]
#
# Range_combined
# Count: 3358
# [388.5, 388.5, 388.5, 388.5, 407.0, 407.0, 369.59999999999997, 369.59999999999997, 369.59999999999997, 369.59999999999997]
#
# Range_city
# Count: 3358
# [351.5, 351.5, 351.5, 351.5, 351.5, 351.5, 316.79999999999995, 316.79999999999995, 316.79999999999995, 316.79999999999995]
#
# Range_highway
# Count: 3358
# [462.5, 462.5, 462.5, 462.5, 481.0, 481.0, 448.79999999999995, 448.79999999999995, 448.79999999999995, 448.79999999999995]
#
# Wheelbase_inches
# Count: 3358
# [113.8, 113.8, 113.8, 113.8, 113.8, 113.8, 105.1, 105.1, 105.1, 105.1]
#
# Length_inches
# Count: 3358
# [198.4, 198.4, 198.4, 198.4, 198.4, 198.4, 182.2, 182.2, 182.2, 182.2]
#
# Width_inches
# Count: 3358
# [78.7, 78.7, 78.7, 78.7, 78.7, 78.7, 70.6, 70.6, 70.6, 70.6]
#
# Height_inches
# Count: 3358
# [67.1, 67.1, 67.1, 67.1, 67.1, 67.1, 55.6, 55.6, 55.6, 55.6]
#
# Ground_clearance_inches
# Count: 3358
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 4.4, 4.4, 4.4, 4.4]
#
# Turning_diameter_ft
# Count: 3358
# [40.5, 40.5, 40.5, 40.5, 40.5, 40.5, 36.8, 36.8, 36.8, 36.8]
#
# Front_wheel_size_inches
# Count: 3358
# ['20 X 9', '20 X 9', '19 X 8.5', '20 X 9', '19 X 8.5', '20 X 9', '18 X 7.5', '18 X 7.5', '17 X 7', '17 X 7']
#
# Rear_wheel_size_inches
# Count: 3358
# ['20 X 9', '20 X 9', '19 X 8.5', '20 X 9', '19 X 8.5', '20 X 9', '18 X 7.5', '18 X 7.5', '17 X 7', '17 X 7']
#
# Same_size_wheels
# Count: 3358
# [True, True, True, True, True, True, True, True, True, True]
#
# Seating_capacity
# Count: 3358
# ['7', '7', '7', '7', '7', '7', '5', '5', '5', '5']
#
# Cabin_volume_cubic_ft
# Count: 3358
# [139.1, 139.1, 139.1, 139.1, 139.1, 139.1, 89.3, 89.3, 89.3, 89.3]
#
# Cargo_space_cubic_ft
# Count: 3358
# [95.0, 95.0, 95.0, 95.0, 95.0, 95.0, 12.4, 12.4, 12.4, 12.4]
#
# GVWR_pounds
# Count: 3358
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
#
# Curb_weight_pounds
# Count: 3358
# [4529.0, 4565.0, 4503.0, 4534.0, 4271.0, 4297.0, 3148.0, 3144.0, 3122.0, 3095.0]
#
# Payload_capacity_pounds
# Count: 3358
# ['NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA']
#
# Towing_capacity_pounds
# Count: 3358
# [5000.0, 5000.0, 5000.0, 5000.0, 3500.0, 3500.0, 'NA', 'NA', 'NA', 'NA']

# %% [markdown]
# If not all lists are the same length (in item count), trim all lists to match the item count of the shortest list. DataFrames require that all lists of data be the same length (that is, that all columns have the same number of items).
#
# Note: This would happen only if the procedure is stopped early. Otherwise, all lists will be the same length.

# %%
for k, v in vehicle_specs.items():
    if len(v) > min_len:
        vehicle_specs[k] = v[:min_len]

# %%
df = pd.DataFrame(vehicle_specs)

print('Rows:\t', df.shape[0], '\nCols:\t', df.shape[1], '\n\n', sep = '')

df.head(10)
# Out:
# Rows:	3358
# Cols:	47
#    Trim_ID   Make  ... Payload_capacity_pounds  Towing_capacity_pounds
# 0   419574  Acura  ...                      NA                    5000
# 1   419576  Acura  ...                      NA                    5000
# 2   419573  Acura  ...                      NA                    5000
# 3   419575  Acura  ...                      NA                    5000
# 4   419577  Acura  ...                      NA                    3500
# 5   419578  Acura  ...                      NA                    3500
# 6   423562  Acura  ...                      NA                      NA
# 7   423561  Acura  ...                      NA                      NA
# 8   423560  Acura  ...                      NA                      NA
# 9   423559  Acura  ...                      NA                      NA
#
# [10 rows x 47 columns]

# %% [markdown]
# ## Examine the values in each column, to see frequency and distribution

# %%
for col in df:
    if len(df[col].unique()) > 20:
        continue
    print(df[col].value_counts())
    print('\n\n')
# Out:
# 2022    1331
# 2021    1125
# 2019     137
# 2020     125
# 2016      79
# 2017      78
# 2013      70
# 2014      67
# 2011      63
# 2018      61
# 2009      57
# 2012      54
# 2015      46
# 2010      37
# 2008      28
# Name: Year, dtype: int64
#
#
#
# suv              1094
# sedan             629
# pickup            614
# van               312
# coupe             271
# hatchback         175
# convertible       166
# station wagon      53
# station-wagon      23
#                    18
# targa               3
# Name: Body_style, dtype: int64
#
#
#
# foreign     2563
# domestic     744
# unknown       51
# Name: Origin, dtype: int64
#
#
#
# Rear Wheel Drive     932
# All Wheel Drive      925
# Front Wheel Drive    875
# Four Wheel Drive     593
# 4-Wheel Drive         12
# All-Wheel Drive       11
# Front wheel drive      5
# Rear-Wheel Drive       4
# Rear wheel drive       1
# Name: Drivetrain, dtype: int64
#
#
#
# Automatic w/OD                        1827
# Automatic                              652
# CVT w/OD                               263
# Auto-Shift Manual w/OD                 222
# Manual w/OD                            197
# Manual                                  81
# Automatic w/Manual Shift                26
# Automatic w/manual shift                15
# Automatic/CVT w/OD                      14
# HD Automatic                            12
# Multi-Speed Automatic w/OD              11
# Continuously Variable Ratio             11
# Sportronic Auto w/OD                     7
# Automatic,                               6
# CVT                                      4
# NA                                       4
# Continuously variable ratio              4
# Continuously Variable Transmission       2
# Name: Transmission_type, dtype: int64
#
#
#
# 8     958
# 6     804
# 10    483
# 1     299
# 7     287
# 9     258
# 5     177
# 4      79
# 2      11
# NA      2
# Name: Transmission_gears, dtype: int64
#
#
#
# True     2974
# False     384
# Name: Same_size_wheels, dtype: int64
#
#
#
# 5     1834
# 6      385
# 4      361
# 2      293
# 7      243
# 3      114
# 8       81
# 12      32
# 10       8
# 15       6
# 1        1
# Name: Seating_capacity, dtype: int64

# %% [markdown]
# # Save the DataFrame as a .csv file and as a .db SQLite database

# %% [markdown]
# First, as a .csv

# %%
df.to_csv('vehicle_specs.csv', encoding='latin-1', index=False)

# %% [markdown]
# Next, as a SQLite database.
#
# To run this cell, select all text in the cell and press `ctrl` + `/` to remove the comments (`#`). Then, run the cell (`ctrl` + `enter`).

# %%
# # establish connection
# conn = sqlite3.connect('vehicle_specs.db')

# # run SQL -- this will create the table, too
# df.to_sql(name='vehicles', con=conn, if_exists='replace', index=False)

# # Note: there is no need for conn.commit(), the changes are automatically saved

# # Close the connection object
# conn.close()

# # test that the data was loaded correctly
# df_new = pd.read_sql(sql="SELECT * FROM vehicles", con=conn)

# df_new

# %% [markdown]
# # Import vehicle sales data (by model), from GoodCarBadCar.net
#
# **NOTE:** I first checked GoodCarBadCar.net's [`robots.txt`](https://www.goodcarbadcar.net/robots.txt) to verify that web scraping is allowed. The pages I will use are permitted.

# %%
# URLs with model sales data:
# https://www.goodcarbadcar.net/2019-us-vehicle-sales-figures-by-model/
# https://www.goodcarbadcar.net/2020-us-vehicle-sales-figures-by-model/
# https://www.goodcarbadcar.net/2021-us-vehicle-sales-figures-by-model/

page = BeautifulSoup(requests.get('https://www.goodcarbadcar.net/2019-us-vehicle-sales-figures-by-model/').text, 'html.parser')
tbl = page.find('table', {'id': 'table_3'})

df_sales = pd.read_html(str(tbl), flavor='bs4')[0]

df_sales.head()
# Out:
#        Model   Jan   Feb   Mar   Apr   May  ...   Jul   Aug   Sep   Oct   Nov   Dec
# 0  Acura ILX   805  1047  1289  1152  1351  ...  1224  1439  1078  1430  1253  1305
# 1  Acura MDX  2968  3833  3982  3339  4425  ...  4788  5976  3833  4368  4784  5636
# 2  Acura NSX    31    22    26    23    30  ...    10    25    16    15    11    10
# 3  Acura RDX  4172  4965  5835  4926  5415  ...  4934  5459  4384  5888  5767  6263
# 4  Acura RLX   119   127   135   151    91  ...    42    38    46    68    80    72
#
# [5 rows x 13 columns]
